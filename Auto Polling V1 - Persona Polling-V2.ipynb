# %%
import os
import glob
import json
import Utils.Chat_GPT_Funcs as GPT
import concurrent.futures
import os
import string
import tiktoken

# %% [markdown]
# # Load in the 343 Personas that mimic the study done

# %%
# Open the JSON file in read mode and load its contents
file_path = "new_personas_343_shortened_ind.json"
with open(file_path, "r") as json_file:
    personas = json.load(json_file)
    
#personas = personas[:3]
print("Total Personas:", len(personas))
# Out:
# Total Personas: 343

# %%
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
num_tokens_from_string(str(personas[75]), "cl100k_base")
# Out:
# 635

# %%
lens = []
for p in personas:
    lens.append(num_tokens_from_string(str(p), "cl100k_base"))

# %%
sum(lens)/343
# Out:
# 641.0699708454811

# %%
#personas[75]

# %% [markdown]
# # Load the survey questions
#     - Using questions from phone interview

# %%
class Question:
    def __init__(self, number, question, possible_responses):
        self.number = number
        self.question = question
        self.possible_responses = possible_responses

    def format_for_gpt(self):
        formatted_question = self.question + '\n'
        formatted_responses = '\n'.join(self.possible_responses)

        return formatted_question + formatted_responses

# %%
questions = [
    Question(1, "Do you plan to vote in the 2022 midterm election?", ["Yes", "No", "Neither"]),
    Question(2, "At this point in time, do you approve or disapprove of President Joe Biden’s performance in office?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(3, "Do you approve or disapprove of Biden’s student loan forgiveness plan?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(4, "At this point in time, do you approve or disapprove of the performance of the US Congress?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(5, "When electing the United States president, do you think we should amend the Constitution to allow the candidate who receives the most votes to win, or do you think we should keep the current system where the candidate who wins the Electoral College vote wins?", ["Amend the Constitution", "Keep the current system"]),
    Question(6, "At this point in time, do you approve or disapprove of Governor Greg Gianforte’s job performance?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(7, "Gianforte’s administration recently attempted to implement a rule banning transgender people from changing their designated sex status on their birth certificate. Do you think transgender people should be able to change the sex on their birth certificate?", ["Yes", "No", "Neither Yes/No"]),
    Question(8, "Are you in US House District 1 or 2?", ["District 1", "District 2", "Don't Know"]),
    Question(9, "If you had to choose today, which of the following candidates would you choose to support for House Representative in District 1?", ["Zinke (R)","Tranel (D)", "Lamb (L)", "Don't Know"]),
    Question(10, "At this point in time, do you approve or disapprove of Congressperson Matt Rosendale’s job performance?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(11, "If you had to choose today, which of the following candidates would you choose to support for House Representative in District 2?", ["Rosendale (R)","Ronning (D)", "Rankin (L)", "Buchanan (I)", "Don't Know"]),
    Question(12, "At this point in time, do you approve or disapprove of Senator Steve Daines’ job performance?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(13, "At this point in time, do you approve or disapprove of Senator Jon Tester’s job performance?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(14, "Do you trust your representatives’ ability to govern efficiently and in a non-divisive manner?", ["Trust", "Distrust", "Neither Trust/Distrust"]),
    Question(15, "Do you trust your local police or sheriff’s department?", ["Trust", "Distrust", "Neither Trust/Distrust"]),
    Question(16, "Have you heard of the Indian Education for All law?", ["Yes", "No", "Neither Yes/No"]),
    Question(17, "The Indian Education for All law is based on a Montana constitutional requirement to encourage learning about American Indian culture and history. Do you believe the money from this law is being used effectively to educate the general student body within Montana’s school system?", ["Yes", "No", "Neither Yes/No"]),
    Question(18, "Do you agree or disagree that there is a mental health crisis in Montana?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(19, "Do you agree or disagree that more fun indoor activities could help the depression rate in Montana?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(20, "Do you agree or disagree that businesses in your community are struggling to find employees?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(21, "Do you agree or disagree that current Montana agricultural practices are environmentally sustainable?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(22, "Do you agree or disagree that Montana officials should work to protect public lands?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(23, "Do you agree or disagree with the Supreme Court's decision to overturn Roe v. Wade?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(24, "When it comes to abortion issues, would you consider yourself to be pro-life or pro-choice?", ["Pro-life", "Pro-choice", "Neither Pro-life/Pro-choice"]),
    Question(25, "Do you agree or disagree with the efforts to remove potentially controversial books from public schools?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(26, "Do you agree or disagree that teachers with a clean background check and training should be allowed to carry a gun in the classroom?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(27, "Do you agree or disagree with using the death penalty as punishment for convicted murder?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(28, "Do you trust mainstream media?", ["Trust", "Distrust", "Neither Trust/Distrust"])
]

# %%
len(questions[:13])
# Out:
# 13

# %%
def create_questions_json(questions):
    question_data = []
    for question in questions:
        question_data.append({
            "number": question.number,
            "text": question.question,
            "possible_responses": question.possible_responses
        })

    json_string = json.dumps(question_data)
    return json_string
json_string = create_questions_json(questions[:14])
print(num_tokens_from_string(json_string, "cl100k_base"))
print(json_string)
# Out:
# 787
# [{"number": 1, "text": "Do you plan to vote in the 2022 midterm election?", "possible_responses": ["Yes", "No", "Neither"]}, {"number": 2, "text": "At this point in time, do you approve or disapprove of President Joe Biden\u2019s performance in office?", "possible_responses": ["Approve", "Disapprove", "Neither Approve/Disapprove"]}, {"number": 3, "text": "Do you approve or disapprove of Biden\u2019s student loan forgiveness plan?", "possible_responses": ["Approve", "Disapprove", "Neither Approve/Disapprove"]}, {"number": 4, "text": "At this point in time, do you approve or disapprove of the performance of the US Congress?", "possible_responses": ["Approve", "Disapprove", "Neither Approve/Disapprove"]}, {"number": 5, "text": "When electing the United States president, do you think we should amend the Constitution to allow the candidate who receives the most votes to win, or do you think we should keep the current system where the candidate who wins the Electoral College vote wins?", "possible_responses": ["Amend the Constitution", "Keep the current system"]}, {"number": 6, "text": "At this point in time, do you approve or disapprove of Governor Greg Gianforte\u2019s job performance?", "possible_responses": ["Approve", "Disapprove", "Neither Approve/Disapprove"]}, {"number": 7, "text": "Gianforte\u2019s administration recently attempted to implement a rule banning transgender people from changing their designated sex status on their birth certificate. Do you think transgender people should be able to change the sex on their birth certificate?", "possible_responses": ["Yes", "No", "Neither Yes/No"]}, {"number": 8, "text": "Are you in US House District 1 or 2?", "possible_responses": ["District 1", "District 2", "Don't Know"]}, {"number": 9, "text": "If you had to choose today, which of the following candidates would you choose to support for House Representative in District 1?", "possible_responses": ["Zinke (R)", "Tranel (D)", "Lamb (L)", "Don't Know"]}, {"number": 10, "text": "At this point in time, do you approve or disapprove of Congressperson Matt Rosendale\u2019s job performance?", "possible_responses": ["Approve", "Disapprove", "Neither Approve/Disapprove"]}, {"number": 11, "text": "If you had to choose today, which of the following candidates would you choose to support for House Representative in District 2?", "possible_responses": ["Rosendale (R)", "Ronning (D)", "Rankin (L)", "Buchanan (I)", "Don't Know"]}, {"number": 12, "text": "At this point in time, do you approve or disapprove of Senator Steve Daines\u2019 job performance?", "possible_responses": ["Approve", "Disapprove", "Neither Approve/Disapprove"]}, {"number": 13, "text": "At this point in time, do you approve or disapprove of Senator Jon Tester\u2019s job performance?", "possible_responses": ["Approve", "Disapprove", "Neither Approve/Disapprove"]}, {"number": 14, "text": "Do you trust your representatives\u2019 ability to govern efficiently and in a non-divisive manner?", "possible_responses": ["Trust", "Distrust", "Neither Trust/Distrust"]}]

# %% [markdown]
# # Initialize Survey Responses
#     - A survey response will each have
#         - Persona responding
#         - Dictionary of responses mapped to the question number
#             - Doing dictionary instead of list just in case of a failure of gpt to answer a question
#             - The indices will have correct values

# %%
import threading
class SurveyResponse:
    def __init__(self, person):
        self.person = person
        self.survey_responses = {}
        self.lock = threading.Lock()  # Create a lock for synchronization


    def ask_question(self, question):
        global total_prompt_tokens, total_completion_tokens
        # Load the Persona role and question
        print("got here, qn", question.number)
        persona_role = GPT.open_file(f"Prompts/Polling/persona_role.txt").replace('<<PERSONA>>', str(self.person))
        question_in = GPT.open_file("Prompts/Polling/question_in.txt").replace('<<QUESTION>>', question.format_for_gpt())
        
        #print(persona_role, question_in)
        try:
            resp, usage = GPT.chat_gpt(question_in, engine = 'gpt-3.5-turbo' , role = persona_role, temp = 0.25, tokens = 300)
            print("GPT ran")
        except:
            resp = ""
            usage = 0
    
        total_completion_tokens += usage['completion_tokens']
        total_prompt_tokens += usage['prompt_tokens']
    
        with self.lock:  # Acquire the lock before modifying the dictionary
            print(resp)
            self.survey_responses[question.number] = resp
        print("sv",self.survey_responses[question.number])
        
    def __str__(self):
        response_str = f"Survey Response for: {self.person}\n"
        response_str += "Survey Responses:\n"
        for question_number, response in self.survey_responses.items():
            response_str += f"Question {question_number}: {response}\n"
        return response_str

# %%
SURVEY_RESPONSES = []
for p in personas:
    SURVEY_RESPONSES.append(SurveyResponse(p))
print("Total Surveys:", len(SURVEY_RESPONSES))
# Out:
# Total Surveys: 343

# %% [markdown]
# # Conduct Survey to Personas

# %% [markdown]
# ## Saving Function
#     - After each question, save data to be safe

# %%
class SurveyResponseEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, SurveyResponse):
            return {
                "person": obj.person,
                "survey_responses": obj.survey_responses
            }
        return super().default(obj)

# %%
qc = 0

total_prompt_tokens = 0
total_completion_tokens = 0

# def ask_question_threaded(SURVEY_RESPONSE, question):
#     SURVEY_RESPONSE.ask_question(question)
    
def ask_question_threaded(SURVEY_RESPONSE, question):  
    global total_prompt_tokens, total_completion_tokens
    # Load the Persona role and question
    persona_role = GPT.open_file(f"Prompts/Polling/persona_role.txt").replace('<<PERSONA>>', str(SURVEY_RESPONSE.person))
    question_in = GPT.open_file("Prompts/Polling/question_in.txt").replace('<<QUESTION>>', question.format_for_gpt())

    #print(persona_role, question_in)
    try:
        resp, usage = GPT.chat_gpt(question_in, engine = 'gpt-3.5-turbo' , role = persona_role, temp = 0.25, tokens = 250)
    except:
        resp = ""
        usage = 0

    total_completion_tokens += usage['completion_tokens']
    total_prompt_tokens += usage['prompt_tokens']

    SURVEY_RESPONSE.survey_responses[str(question.number)] = resp

for question in questions:
#     if qc == 1:
#         break
#     qc += 1
    # Create a thread pool executor with 10 workers
    print(f"Starting Question: {str(question.number)}\n")
    with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
        # Submit tasks to the executor for each persona
        futures = [executor.submit(ask_question_threaded, SURVEY_RESPONSE, question) for SURVEY_RESPONSE in SURVEY_RESPONSES]

        # Wait for all tasks to complete
        concurrent.futures.wait(futures)
    
        # Save responses as JSON
    with open("survey_responses_343.json", "w") as file:
        json.dump(SURVEY_RESPONSES, file, cls=SurveyResponseEncoder, indent=4)

print("Total Prompt Tokens:", total_prompt_tokens)
print("Total Completion Tokens:", total_completion_tokens)
print()
print("Token Cost = $", str((total_prompt_tokens+total_completion_tokens)/1000*0.002))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 27
#      23     total_prompt_tokens += usage['prompt_tokens']
#      25     SURVEY_RESPONSE.survey_responses[str(question.number)] = resp
# ---> 27 for question in questions:
#      28 #     if qc == 1:
#      29 #         break
#      30 #     qc += 1
#      31     # Create a thread pool executor with 10 workers
#      32     print(f"Starting Question: {str(question.number)}\n")
#      33     with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
#      34         # Submit tasks to the executor for each persona
#
# NameError: name 'questions' is not defined

# %%
class SurveyResponseEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, SurveyResponse):
            return {
                "person": obj.person,
                "survey_responses": obj.survey_responses
            }
        return super().default(obj)

    # Save responses as JSON
with open("survey_responses_343_2.json", "w") as file:
    json.dump(SURVEY_RESPONSES, file, cls=SurveyResponseEncoder, indent=4)

# %% [markdown]
# # Analyze Results

# %%
resps_out = {}
for i in range(len(questions)):
    resps_out[i+1] = []

for i in range(len(questions)):
    for s in SURVEY_RESPONSES:
        
        try:
            resp_data = json.loads(s.survey_responses[str(i+1)])
            resp_val = resp_data['Answer']
            resps_out[i+1].append(resp_val)   
        except Exception as e:
            print("Invalid Format", str(e))
            continue

# %%
def count_responses(responses):
    # Count occurrences of each unique value
    counts = {}
    total_responses = len(responses)

    for response in responses:
        if response not in counts:
            counts[response] = 0
        counts[response] += 1

    # Print counts and percentages
    print("Counts of each response:")
    for response, count in counts.items():
        percentage = (count / total_responses) * 100
        print(f"{response}: {count} ({percentage:.2f}%)")

# %%
for i, resp in resps_out.items():
    count_responses(resp)
    print()
# Out:
# Counts of each response:
# Yes: 3 (100.00%)
#
# Counts of each response:
# Disapprove: 1 (33.33%)
# Approve: 2 (66.67%)
#
# Counts of each response:
# Disapprove: 2 (66.67%)
# Approve: 1 (33.33%)
#
# Counts of each response:
# Neither Approve/Disapprove: 2 (66.67%)
# Disapprove: 1 (33.33%)
#
# Counts of each response:
# Keep the current system: 3 (100.00%)
#
# Counts of each response:
# Approve: 3 (100.00%)
#
# Counts of each response:
# Yes: 3 (100.00%)
#
# Counts of each response:
# District 1: 2 (66.67%)
# Don't Know: 1 (33.33%)
#
# Counts of each response:
# Zinke (R): 2 (66.67%)
# Don't Know: 1 (33.33%)
#
# Counts of each response:
# Approve: 3 (100.00%)
#
# Counts of each response:
# Rosendale (R): 2 (66.67%)
# I would need to research and understand the candidates and their platforms before making a decision on who to support. At this time, I do not have enough information to choose a candidate.: 1 (33.33%)
#
# Counts of each response:
# Approve: 3 (100.00%)
#
# Counts of each response:
# Approve: 2 (66.67%)
# Neither Approve/Disapprove: 1 (33.33%)
#
# Counts of each response:
# Distrust: 2 (66.67%)
# Neither Trust/Distrust: 1 (33.33%)
#
# Counts of each response:
# Trust: 2 (66.67%)
# Neither Trust/Distrust: 1 (33.33%)
#
# Counts of each response:
# Yes: 3 (100.00%)
#
# Counts of each response:
# Yes: 3 (100.00%)
#
# Counts of each response:
# Agree: 3 (100.00%)
#
# Counts of each response:
# Agree: 3 (100.00%)
#
# Counts of each response:
# Agree: 1 (33.33%)
# Neither Agree/Disagree: 2 (66.67%)
#
# Counts of each response:
# Neither Agree/Disagree: 2 (66.67%)
# Disagree: 1 (33.33%)
#
# Counts of each response:
# Agree: 3 (100.00%)
#
# Counts of each response:
# Agree: 2 (66.67%)
# Disagree: 1 (33.33%)
#
# Counts of each response:
# Pro-life: 2 (66.67%)
# Pro-choice: 1 (33.33%)
#
# Counts of each response:
# Disagree: 3 (100.00%)
#
# Counts of each response:
# Agree: 1 (33.33%)
# Disagree: 2 (66.67%)
#
# Counts of each response:
# Agree: 2 (66.67%)
# Disagree: 1 (33.33%)
#
# Counts of each response:
# Distrust: 1 (33.33%)
# Neither Trust/Distrust: 2 (66.67%)

# %%
def thread_ask_question(i, question):
    global total_prompt_tokens, total_completion_tokens
    persona_role = GPT.open_file(f"Prompts/Polling/persona_gpt.txt").replace('<<PERSONA>>', str(personas[i]))
    question_in = GPT.open_file("Prompts/Polling/question_in.txt").replace('<<QUESTION>>', question.format_for_gpt())
    print(persona_role, question_in)
    return ""
    try:
        resp, usage = GPT.chat_gpt(question_in, engine = 'gpt-3.5-turbo' , role = persona_role, temp = 0.25, tokens = 300)
    except:
        return "",0
    
    total_completion_tokens += usage['completion_tokens']
    total_prompt_tokens += usage['prompt_tokens']
    
    print(i, resp)
    return resp

# %%
responses = []

total_prompt_tokens = 0
total_completion_tokens = 0
def thread_func(i):
    global total_prompt_tokens, total_completion_tokens
    persona_role = GPT.open_file(f"Prompts/Polling/persona_gpt.txt").replace('<<PERSONA>>', str(personas[i]))
    question_in = GPT.open_file("Prompts/Polling/multi_question.txt").replace('<<QUESTION>>', json_string)
    print(num_tokens_from_string(persona_role + question_in, "cl100k_base"))
    try:
        resp, usage = GPT.chat_gpt(question_in, engine = 'gpt-4' , role = persona_role, temp = 0.6, tokens = 2048)
    except:
        return "",0
    total_completion_tokens += usage['completion_tokens']
    total_prompt_tokens += usage['prompt_tokens']
    print(i, resp)
    return resp

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    responses = list(executor.map(thread_func, range(50,51)))

print("Total Prompt Tokens:", total_prompt_tokens)
print("Total Completion Tokens:", total_completion_tokens)
print()
print("Token Cost = $", str((total_prompt_tokens+total_completion_tokens)/1000*0.002))
# Out:
# 1566
# 50 {
#     "1": {
#         "Reasoning": "As a conservative, I have always voted and usually support Republican candidates due to their alignment with my values of smaller government, lower taxes, and individual freedom. I believe it's important to participate in elections to make my voice heard.",
#         "Answer": "Yes"
#     },
#     "2": {
#         "Reasoning": "As a conservative, I generally disagree with President Biden's policies and believe his administration is leading the country in the wrong direction, with bigger government and more spending.",
#         "Answer": "Disapprove"
#     },
#     "3": {
#         "Reasoning": "I believe in personal responsibility and self-sufficiency. I think that forgiving student loans would encourage people to rely on the government and not take responsibility for their own debts.",
#         "Answer": "Disapprove"
#     },
#     "4": {
#         "Reasoning": "As a conservative, I am disappointed with the performance of Congress, as I believe they are not doing enough to promote smaller government, lower taxes, and individual freedom.",
#         "Answer": "Disapprove"
#     },
#     "5": {
#         "Reasoning": "I believe the Electoral College system is important for ensuring that rural states like Montana have a voice in presidential elections. Changing the system could lead to candidates focusing only on more populous states.",
#         "Answer": "Keep the current system"
#     },
#     "6": {
#         "Reasoning": "As a conservative, I generally support Governor Greg Gianforte's policies and believe he is working to promote smaller government and individual freedom in Montana.",
#         "Answer": "Approve"
#     },
#     "7": {
#         "Reasoning": "I believe that people should be able to live their lives as they see fit, but I also think that changing one's sex on a birth certificate could lead to confusion and potential legal issues.",
#         "Answer": "No"
#     },
#     "8": {
#         "Reasoning": "As a resident of rural Montana, I am unsure of which congressional district I belong to.",
#         "Answer": "Don't Know"
#     },
#     "9": {
#         "Reasoning": "As a conservative, I would be more likely to support Zinke (R) due to his alignment with my values of smaller government, lower taxes, and individual freedom.",
#         "Answer": "Zinke (R)"
#     },
#     "10": {
#         "Reasoning": "As a conservative, I generally support Congressperson Matt Rosendale's policies and believe he is working to promote smaller government and individual freedom.",
#         "Answer": "Approve"
#     },
#     "11": {
#         "Reasoning": "As a conservative, I would be more likely to support Rosendale (R) due to his alignment with my values of smaller government, lower taxes, and individual freedom.",
#         "Answer": "Rosendale (R)"
#     },
#     "12": {
#         "Reasoning": "As a conservative, I generally support Senator Steve Daines' policies and believe he is working to promote smaller government and individual freedom.",
#         "Answer": "Approve"
#     },
#     "13": {
#         "Reasoning": "As a conservative, I generally disagree with Senator Jon Tester's policies and believe he is not doing enough to promote smaller government, lower taxes, and individual freedom.",
#         "Answer": "Disapprove"
#     },
#     "14": {
#         "Reasoning": "I am concerned about the increasing divisiveness in politics and the inability of our representatives to work together effectively. I hope for more cooperation and efficient governance, but currently, I am not confident in their ability to do so.",
#         "Answer": "Distrust"
#     }
# }
# Total Prompt Tokens: 1577
# Total Completion Tokens: 765
#
# Token Cost = $ 0.004684000000000001

# %% [markdown]
# # Process Responses

# %%
def count_answers(strings):
    count_disapprove = 0
    count_approve = 0
    count_neither = 0

    for string in strings:
        if string == "Disapprove":
            count_disapprove += 1
        elif string == "Approve":
            count_approve += 1
        elif string == "Neither Approve/Disapprove":
            count_neither += 1

    return count_disapprove, count_approve, count_neither

# %%
def count_yes_no(strings):
    count_disapprove = 0
    count_approve = 0
    count_neither = 0

    for string in strings:
        if string == "Yes":
            count_disapprove += 1
        elif string == "No":
            count_approve += 1
        elif string == "Neither Approve/Disapprove":
            count_neither += 1

    return count_disapprove, count_approve, count_neither

# %%
answers = []
for resp in responses:
    try:
        data = json.loads(resp)
    except:
        print("failed")
        continue
    answers.append(data['Answer'])

# %%
disapprove_count, approve_count, neither_count = count_yes_no(answers)
print("Disapprove count:", disapprove_count)
print("Approve count:", approve_count)
print("Neither count:", neither_count)
# Out:
# Disapprove count: 13
# Approve count: 17
# Neither count: 0

# %%
responses_2 = []
#question = "Do you plan to vote in the 2024 midterm election?\n Yes\n No\n Undecided\n Please note, you are allowed to say no and not voted"

question = "At this point in time, do you approve or disapprove of President Joe Biden's performance in office?\nApprove\nDisapprove\nNeither Approve/Disapprove"

#question = "Do you approve or disapprove of President Joe Biden's student loan forgiveness plan?\nApprove\nDisapprove\nNeither Approve/Disapprove"

total_prompt_tokens = 0
total_completion_tokens = 0


def thread_func(i):
    global total_prompt_tokens, total_completion_tokens
    persona_role = GPT.open_file(f"Prompts/Polling/persona_role.txt").replace('<<PERSONA>>', str(personas[i]))
    question_in = GPT.open_file("Prompts/Polling/question_in.txt").replace('<<QUESTION>>', json_string)
    #print(persona_role, question_in)
    resp, usage = GPT.chat_gpt(question_in, engine = 'gpt-3.5-turbo' , role = persona_role, temp = 0.1, tokens = 300)
    total_completion_tokens += usage['completion_tokens']
    total_prompt_tokens += usage['prompt_tokens']
    print(i, resp)
    return resp

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    responses_2 = list(executor.map(thread_func, range(len(personas))))

print("Total Prompt Tokens:", total_prompt_tokens)
print("Total Completion Tokens:", total_completion_tokens)
print()
print("Token Cost = $", str((total_prompt_tokens+total_completion_tokens)/1000*0.002))
# Out:
# 9 {
#     "Reasoning": "As Lisha Patterson, a conservative individual, I tend to disagree with President Joe Biden's policies and political views. Additionally, I consume media outlets that cater to conservative political views, which often criticize and oppose President Biden's actions. Therefore, I would disapprove of President Joe Biden's performance in office at this point in time.",
#     "Answer": "Disapprove"
# }
# 2 {
#     "Reasoning": "As Sean Foster, a conservative individual who tends to vote for Republican candidates, I am likely to disapprove of President Joe Biden's performance in office. Additionally, my media consumption habits may expose me to news outlets that are critical of the current administration. However, I also believe in researching and understanding the policies and actions of elected officials before forming an opinion. Therefore, I will review President Biden's performance in office based on his policies and actions that align with my political beliefs and values.",
#     "Answer": "Disapprove"
# }
# 6 {
#     "Reasoning": "As Tyler King, a conservative construction worker from Montana who identifies as a Republican, I am likely to disapprove of President Joe Biden's performance in office. Based on my political affiliation and media consumption habits, I am likely to consume news outlets that are critical of the current administration and its policies. Additionally, I may disagree with many of the policies and positions that President Biden and the Democratic Party have put forth, such as higher taxes, increased government regulation, and progressive social policies. Therefore, I am likely to disapprove of President Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# 4 {
#     "Reasoning": "As Richard Hernandez, a conservative political affiliate, I tend to lean towards disapproving of President Joe Biden's performance in office. I may not agree with his policies and decisions, especially those that may not align with my conservative values. Additionally, my media consumption may also influence my opinion of his performance. However, I also believe in being an informed voter and taking the time to research each candidate and their policies before making a decision. Therefore, I will consider his performance based on his actions and decisions as President so far.",
#     "Answer": "Disapprove"
# }
# 7 {
#     "Reasoning": "As Charlotte Harris, a right-leaning individual, I tend to have a negative view of President Joe Biden's policies and actions. However, I also believe in giving credit where it is due. I would consider factors such as his handling of the COVID-19 pandemic, his economic policies, and his foreign policy decisions. Based on my media consumption and political affiliation, I am likely to consume media outlets that are critical of President Biden. However, I would also consider the impact of his policies on my personal and professional life, as well as the future of the country. Overall, I would lean towards disapproving of President Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# 5 {
#     "Reasoning": "As Mae Foster, a conservative individual who tends to vote for Republican candidates, I am likely to disapprove of President Joe Biden's performance in office. Additionally, my media consumption, which includes Fox News and The Rush Limbaugh Show, is likely to provide me with a negative view of the current administration. However, I also believe in researching and understanding the candidates and their policies before making a decision. Therefore, I would need to review President Biden's policies and actions in office before making a final decision on whether to approve or disapprove of his performance.",
#     "Answer": "Disapprove"
# }
# 0 {
#     "Reasoning": "As a moderate with no specific political affiliation, Imogen Bailey might have a balanced and pragmatic approach towards evaluating President Joe Biden's performance in office. She is likely to consider his policies, actions, and decisions based on their impact on the country and its citizens, rather than their alignment with a particular ideology or party. She might also be influenced by the media outlets she consumes, which are likely to provide a diverse range of perspectives on the current administration. However, without any specific information about her personal views on Biden's policies or actions, it is difficult to determine her level of approval or disapproval.",
#
#     "Answer": "Neither Approve/Disapprove"
# }
# 1 {
#     "Reasoning": "As Tyler Patterson, a conservative individual from rural Montana, I am likely to disapprove of President Joe Biden's performance in office. Based on my political affiliation and media consumption habits, I am likely to consume media outlets that are critical of President Biden and his policies. Additionally, as someone who values individual freedom and self-reliance, I may disagree with some of the policies and initiatives that President Biden has put forth, such as increased government spending and regulation. However, it is important to note that my personal beliefs and opinions may not align with those of other individuals, and they may have a different perspective on President Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# 8 {
#     "Reasoning": "As Jeffrey Baker, a conservative accountant, I tend to vote for candidates who align with my conservative political affiliation and values. However, I also take into consideration the candidate's stance on financial and economic issues, as those are important to me as an accountant. Based on my political affiliation, I may not necessarily approve of President Joe Biden's policies and actions. However, as an individual, I believe in giving credit where it is due. Therefore, I would say that I approve of President Joe Biden's performance in office so far, especially in terms of his handling of the COVID-19 pandemic and the vaccine rollout. However, I may not necessarily agree with all of his policies and actions, and I will continue to monitor his performance in office.",
#     "Answer": "Approve"
# }
# 3 {
#     "Reasoning": "As a right-leaning individual, Kevin Evans may not be particularly fond of President Joe Biden's policies and political views. However, as someone who takes the time to research and educate himself on the candidates and their policies before making a decision, he may be willing to give President Biden a chance and evaluate his performance based on his actions and decisions as President. Additionally, as a retired business owner, Kevin Evans may be interested in policies related to the economy and job creation, and may approve of President Biden's efforts to promote economic growth and recovery. Overall, based on his political affiliation and personal values, Kevin Evans may lean towards disapproving of President Biden's performance in office, but may also be open to evaluating his actions and decisions before making a final judgement.",
#     "Answer": "Neither Approve/Disapprove"
# }
# 10 {
#     "Reasoning": "As a conservative individual, Stacy Johnson may not approve of President Joe Biden's policies and actions. However, as a professional market research recruiter, she may also consider the positive aspects of his performance, such as his efforts to combat the COVID-19 pandemic and his focus on infrastructure and climate change. Ultimately, her political affiliation and personal beliefs may heavily influence her decision.",
#     "Answer": "Disapprove"
# }
# 11 {
#     "Reasoning": "As Hunter Young, a conservative-leaning individual, I am likely to disapprove of President Joe Biden's performance in office. I may disagree with his policies and actions, particularly those related to government spending, taxes, and individual freedoms. Additionally, I may not trust media outlets that are generally supportive of President Biden, which may influence my perception of his performance. However, I also believe in researching each candidate and their policies before making a decision. Therefore, I will consider any positive actions or policies that President Biden has implemented before making a final decision.",
#     "Answer": "Disapprove"
# }
# 18 {
#     "Reasoning": "As a right-leaning individual, I am likely to disapprove of President Joe Biden's performance in office. However, I believe in giving every elected official a fair chance to prove themselves. I would consider factors such as his policies, actions, and decisions to determine my approval or disapproval of his performance in office. Additionally, my media consumption may influence my perception of his performance.",
#     "Answer": "Disapprove"
# }
# 12 {
#     "Reasoning": "As Grace Davis, a left-leaning individual who prioritizes issues such as social justice, healthcare, and the environment, I approve of President Joe Biden's performance in office. He has taken steps to address these issues, such as signing executive orders to combat climate change and expand access to healthcare. Additionally, his administration has made efforts to promote diversity and inclusion, which aligns with my values. While there may be areas where I disagree with his policies, overall I believe that he is moving in the right direction and making progress on important issues.",
#     "Answer": "Approve"
# }
# 13 {
#     "Reasoning": "As Felicity Ross, a conservative individual who prioritizes smaller government, lower taxes, and individual freedoms, I am likely to disapprove of President Joe Biden's performance in office. Additionally, I tend to vote for conservative candidates who align with my political beliefs and values, and President Biden's policies and actions may not align with my beliefs. However, I should also consider that my media consumption may have a bias towards conservative news outlets that may not provide a balanced view of President Biden's performance. Ultimately, based on my political beliefs and values, I would disapprove of President Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# 15 {
#     "Reasoning": "As Evan Carter, a conservative individual who prioritizes individual freedoms, lower taxes, and national security, I am likely to disapprove of President Joe Biden's performance in office. Based on my media consumption habits, I am likely to consume media outlets that are critical of the current administration and its policies. Additionally, as someone who has consistently voted for conservative candidates and supported the Republican Party, I am unlikely to approve of a Democratic president's performance in office. While I may not agree with all of President Biden's policies, I am willing to give credit where credit is due and acknowledge any positive actions he takes that align with my values.",
#     "Answer": "Disapprove"
# }
# 16 {
#     "Reasoning": "As Justin Lopez, a conservative farmer and supporter of the Republican Party, I am likely to disapprove of President Joe Biden's performance in office. I prioritize issues that affect rural communities, such as agriculture and land use policies, and I believe in smaller government, lower taxes, and individual freedoms. President Biden's policies and actions, such as his proposed tax increases and environmental regulations, may negatively impact my livelihood as a farmer and go against my conservative values. Additionally, as a conservative, I may not agree with his policies on social issues such as abortion and gun control. Based on my political affiliation and values, I am likely to disapprove of President Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# 14 {
#     "Reasoning": "As Miguel Ortiz, a conservative who tends to vote for the Republican Party, I am likely to disapprove of President Joe Biden's performance in office. I may disagree with his policies and believe that they are not in line with my conservative values. Additionally, as a construction worker, I may be concerned about the impact of his policies on the economy and job creation. However, I also believe in researching and understanding the policies of the candidates before making a decision. Therefore, I would need to review and analyze President Biden's policies and actions before making a final decision on whether to approve or disapprove of his performance in office. However, based on my political affiliation and beliefs, I am more likely to disapprove of his performance at this point in time.",
#     "Answer": "Disapprove"
# }
# 17 {
#     "Reasoning": "As Rosa Juarez, a right-leaning individual, I may be more likely to disapprove of President Joe Biden's performance in office. However, as someone who has not consistently voted in the past and may not have a lot of political experience, I may not have a strong opinion on his performance at this point in time. Additionally, as a housekeeper with limited free time, I may not have had the opportunity to closely follow his actions and policies in office. Therefore, I am neither approving nor disapproving of President Joe Biden's performance in office at this time.",
#     "Answer": "Neither Approve/Disapprove"
# }
# 19 {
#     "Reasoning": "As a right-leaning individual, Walter Watson is likely to have a negative view of President Joe Biden's performance in office. Additionally, his political affiliation and media consumption may have influenced his opinion of the President. However, without more information about specific policies or actions taken by the President, it is difficult to determine Walter's exact opinion. It is possible that he may disapprove of some policies while approving of others. Overall, given his political affiliation and demographic information, it is likely that Walter disapproves of President Joe Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# 25 {
#     "Reasoning": "As Kristine Scott, a moderate with no specific political affiliation, my opinion on President Joe Biden's performance in office is based on his policies and actions. As a Veteran Outreach Coordinator, I am particularly interested in his policies related to veterans' healthcare, education, and economic opportunities. I also value his efforts to address climate change and promote social justice. Based on his actions so far, I approve of President Joe Biden's performance in office.",
#     "Answer": "Approve"
# }
# 21 {
#     "Reasoning": "As Diane Myers, a right-leaning individual, I am likely to have some disagreements with President Joe Biden's policies and political views. However, as a veteran affairs officer, I am also likely to take into consideration the President's stance on issues related to veterans and their access to healthcare and benefits. Based on my personal beliefs and experiences, I believe that it is important for our government to prioritize and improve these services for those who have served our country. Therefore, I am likely to approve of President Joe Biden's performance in office so far, if he has taken steps to improve the lives of veterans. However, I would need to review his policies and actions more closely before making a final decision.",
#     "Answer": "Approve"
# }
# 22 {
#     "Reasoning": "As Patsy Martinez, a conservative individual who tends to vote for Republican candidates, I am likely to disapprove of President Joe Biden's performance in office. I believe that his policies and actions do not align with my conservative values and principles, such as smaller government, lower taxes, and traditional values. Additionally, based on my media consumption habits, I am likely to consume news outlets that are critical of President Biden and his administration. However, as an individual who believes in researching and understanding the candidates and their policies before casting my vote, I would need to review President Biden's specific policies and actions to make a final decision on whether I approve or disapprove of his performance in office.",
#     "Answer": "Disapprove"
# }
# 24 {
#     "Reasoning": "As Koa Raccoon, I tend to lean towards liberal policies and candidates that prioritize the needs of marginalized communities and work towards social and economic justice. Based on my political affiliation and values, I am likely to approve of President Joe Biden's performance in office. Additionally, as someone who has not consistently voted in the past, I may be more forgiving of any shortcomings or mistakes made by the President. However, as a rural construction worker with a lower income and less education, I may not be as informed or engaged with national politics as other individuals. Therefore, my approval or disapproval may be based more on my personal values and beliefs rather than a deep understanding of the President's policies and actions.",
#     "Answer": "Approve"
# }
# 28 {
#     "Reasoning": "As a conservative with a political affiliation that leans towards the Republican party, it is likely that I do not approve of President Joe Biden's performance in office. Additionally, my media consumption may include conservative news outlets that may criticize President Biden's policies and actions. However, as a retired teacher, I also value education and may appreciate some of the policies that President Biden has implemented in that area. Overall, based on my political beliefs and media consumption, I am likely to disapprove of President Joe Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# 29 {
#     "Reasoning": "As Ian Perry, a conservative construction worker from rural Montana, I tend to lean towards conservative political views and values. Based on my political affiliation and media consumption habits, I am likely to consume media outlets that are critical of President Joe Biden and his policies. However, as an informed voter, I also take the time to research and understand each candidate's policies and actions before making a decision. At this point in time, I believe that President Joe Biden's policies and actions do not align with my conservative values and beliefs. Therefore, I disapprove of his performance in office.",
#     "Answer": "Disapprove"
# }
# 23 {
#     "Reasoning": "As Maggie Jones, a moderate with no strict party affiliation, I would base my approval or disapproval of President Joe Biden's performance in office on his actions and policies rather than his party affiliation. I would consider his handling of issues such as the COVID-19 pandemic, the economy, and social justice. Based on my media consumption habits, I am likely to have been exposed to a mix of news sources that may have different opinions on his performance. However, I would prioritize unbiased and trustworthy sources when forming my opinion. Overall, I believe it is too early to make a definitive judgement on his performance, as he has only been in office for a few months. I would prefer to wait and see how his policies and actions play out over time before making a final decision.",
#     "Answer": "Neither Approve/Disapprove"
# }
# 27 {
#     "Reasoning": "As Shannon Garcia, a right-leaning individual, I am likely to have some disagreements with President Joe Biden's policies and political views. However, as a responsible voter, I believe it is important to evaluate a politician's performance based on their actions and accomplishments rather than just their party affiliation. Based on my media consumption and personal research, I am aware that President Biden has taken several actions to address issues such as the COVID-19 pandemic, climate change, and social justice. While I may not agree with all of his policies, I believe that he is making an effort to address important issues and move the country forward. Therefore, I approve of President Joe Biden's performance in office at this point in time.",
#     "Answer": "Approve"
# }
# 26 {
#     "Reasoning": "As Justin Martin, I am a moderate with no strong political affiliations. Therefore, I am likely to evaluate President Joe Biden's performance based on his policies and actions rather than his political party. As a janitor with a lower income and less than a high school education, I may be more concerned with policies that benefit the working class and provide access to education and job training. Based on my personal experiences and future aspirations, I may approve of President Biden's efforts to increase access to healthcare, provide economic relief to those affected by the pandemic, and invest in infrastructure and job creation. However, I may also have concerns about the rising national debt and the potential impact on future generations. Overall, I am likely to evaluate President Biden's performance based on his policies and actions that align with my personal values and aspirations.",
#     "Answer": "Approve"
# }
# 31 {
#     "Reasoning": "As a liberal, I tend to support Democratic candidates and policies. Joe Biden is a Democrat and has a history of supporting issues that are important to me, such as healthcare reform and workers' rights. Additionally, I appreciate his efforts to address climate change and his commitment to social justice issues. While I may not agree with every decision he makes, overall I approve of his performance in office thus far.",
#     "Answer": "Approve"
# }
# 30 {
#     "Reasoning": "As Tracy Mitchell, a conservative individual, I tend to disagree with President Joe Biden's policies and political beliefs. I believe in smaller government, lower taxes, and individual freedoms, which are not aligned with the current administration's policies. Additionally, I consume media outlets that are conservative and may have a negative bias towards the current administration. However, I also believe in giving credit where it is due and acknowledging positive actions taken by the President. Therefore, I will base my decision on President Biden's performance in office so far, rather than my political beliefs or media bias.",
#     "Answer": "Disapprove"
# }
# Error communicating with OpenAI: That model is currently overloaded with other requests. You can retry your request, or contact us through our help center at help.openai.com if the error persists. (Please include the request ID f32ded5dd681115bf617e7562c2934ea in your message.)
# 34 {
#     "Reasoning": "As Gertrude Moore, a liberal voter from rural Montana, I am likely to approve of President Joe Biden's performance in office. I tend to vote for candidates who align with my political beliefs and values, and President Biden's policies and actions align with my liberal views. Additionally, as a farmer or rancher, I appreciate his focus on supporting rural communities and agriculture. However, it is important to note that my approval may be influenced by the media sources I consume, which may have a bias towards President Biden and his policies.",
#     "Answer": "Approve"
# }
# 35 {
#     "Reasoning": "As Caleb Baker, a moderate construction worker living in rural Montana, I tend to evaluate politicians based on their actions and policies rather than their party affiliation. While I may not agree with all of President Biden's policies, I believe that he has shown a willingness to work towards bipartisan solutions and has taken steps to address issues that are important to me, such as infrastructure and healthcare. Additionally, as someone who values the sacrifices made by our service members, I appreciate President Biden's efforts to support our troops and veterans. Overall, I approve of President Biden's performance in office thus far.",
#     "Answer": "Approve"
# }
# 32 {
#     "Reasoning": "As Chelsea Reed, a liberal with a high school education and a retail sales associate living in rural Montana, I am likely to approve of President Joe Biden's performance in office. Based on my media consumption, I am likely to trust and consume media outlets such as CNN, MSNBC, The New York Times, and The Washington Post for national and international news, which have generally been supportive of President Biden's policies and actions. Additionally, as a liberal, I am likely to support his focus on issues such as healthcare, education, and the environment. However, it is important to note that my individual opinion may vary based on my personal experiences and beliefs.",
#     "Answer": "Approve"
# }
# 36 {
#     "Reasoning": "As Tabitha Kelly, I tend to lean left politically and have voted for candidates who align with my values in the past. Based on my political affiliation and values, I approve of President Joe Biden's performance in office so far. I appreciate his efforts to address issues such as the COVID-19 pandemic, climate change, and economic inequality. Additionally, I believe that his policies and actions align with my hopes for the future, such as prioritizing economic justice and access to affordable healthcare and education for all. While there may be areas where I disagree with his policies or actions, overall I believe that he is working towards a better future for all Americans.",
#     "Answer": "Approve"
# }
# 38 {
#     "Reasoning": "As Caroline Lopez, a conservative veteran living in urban Montana, I am likely to have a negative view of President Joe Biden's performance in office. As a conservative, I may disagree with many of his policies and priorities, particularly in areas such as national security and economic growth. Additionally, as a veteran, I may be critical of his handling of military and foreign policy issues. However, it is important to note that I may also take the time to research and evaluate his policies before making a final decision on his performance in office.",
#     "Answer": "Disapprove"
# }
# 37 {
#     "Reasoning": "As Bradley Henderson, a right-leaning individual, I tend to support politicians who align with my political affiliation and prioritize issues that are important to me as a rancher or farmer living in rural Montana. However, I also believe in giving the President a chance to prove himself and his policies. While I may not agree with all of President Biden's policies, I believe it is important to evaluate his performance based on his actions and results so far. Additionally, as a responsible voter, I believe in participating in the democratic process and supporting the elected President, regardless of my personal political beliefs.",
#     "Answer": "Approve"
# }
# 33 {
#     "Reasoning": "As a conservative retired rancher living in rural Montana, I tend to vote for candidates who align with my conservative political affiliation and share my values. President Joe Biden is a Democrat and his policies may not align with my political beliefs. However, I believe in researching and understanding the candidates and their policies before casting my vote. As a retired rancher, I am likely to consume media outlets that align with my conservative political affiliation. Therefore, I may not have a favorable view of President Joe Biden's performance in office. However, as a responsible citizen, I believe in giving credit where it is due and evaluating a politician's performance based on their actions and policies rather than their political affiliation. Therefore, I would like to give President Joe Biden a chance and evaluate his performance based on his actions and policies in office before forming an opinion. At this point in time, I neither approve nor disapprove of President Joe Biden's performance in office.",
#     "Answer": "Neither Approve/Disapprove"
# }
# 39 {
#     "Reasoning": "As Kachina Brown, a conservative rancher from rural Montana, I tend to lean towards conservative policies and values. Therefore, I am more likely to disapprove of President Joe Biden's performance in office. Additionally, I tend to consume media outlets that align with my conservative political affiliation, which may also influence my opinion of the President's performance. However, I also believe in being an informed voter and researching each candidate and their policies before making a decision. Therefore, I will consider the actions and policies of President Biden before making a decision on whether to approve or disapprove of his performance in office.",
#     "Answer": "Disapprove"
# }
# 41 {
#     "Reasoning": "As a left-leaning individual, I am more likely to approve of President Joe Biden's performance in office. Additionally, I am interested in policies that promote social justice, equality, and progressive values, which align with many of the policies that President Biden has proposed. However, I also recognize that no politician is perfect and there may be areas where I disagree with President Biden's policies or actions. Overall, I believe that it is important to evaluate a politician's performance based on their actions and policies, rather than their party affiliation or personal characteristics.",
#     "Answer": "Approve"
# }
# 44 {
#     "Reasoning": "As Ben Powell, a right-leaning individual, I am likely to disapprove of President Joe Biden's performance in office. I tend to support policies that prioritize job creation and economic growth, and I may not agree with the current administration's policies. Additionally, I may consume media outlets that are critical of the current administration, which may further influence my opinion. However, it's important to note that individual opinions may vary based on personal experiences and beliefs.",
#     "Answer": "Disapprove"
# }
# 40 {
#     "Reasoning": "As Trevor Perez, a conservative individual, I am likely to disapprove of President Joe Biden's performance in office. Based on my political affiliation and media consumption habits, I am likely to consume media outlets that are critical of President Biden and his policies. Additionally, as someone who typically votes for Republican candidates, I am likely to disagree with many of the policies and actions taken by the current administration. However, it is important to note that I would still take the time to research and evaluate the specific policies and actions taken by President Biden before making a final decision on my approval or disapproval of his performance in office.",
#     "Answer": "Disapprove"
# }
# 20 {
#     "Reasoning": "As Joyce Ward, I consider myself a moderate and tend to vote for the candidate who I believe will best represent my values and interests, regardless of their party affiliation. While I may not agree with all of President Biden's policies, I believe it is important to give him a chance to lead and address the issues facing our country. Additionally, as a retired farmer living in rural Montana, I may have different priorities and concerns than those living in more urban areas. Overall, I approve of President Biden's performance in office thus far.",
#     "Answer": "Approve"
# }
# 42 {
#     "Reasoning": "As Samuel Romero, a right-leaning individual who tends to vote for right-leaning candidates, I am likely to disapprove of President Joe Biden's performance in office. Additionally, as a blue-collar worker, I may be concerned about policies that could negatively impact the working class, such as tax increases or job loss due to environmental regulations. However, as I have not consistently voted in the past and may not be closely following current political events, I may not have a strong opinion on President Biden's performance in office so far.",
#     "Answer": "Disapprove"
# }
# 43 {
#     "Reasoning": "As Louis Kelly, a left-leaning individual, I generally approve of President Joe Biden's performance in office. I appreciate his efforts to address issues such as climate change, healthcare, and education. Additionally, I believe that his policies are more aligned with the needs of working-class Americans like myself. However, I also recognize that no president is perfect and there may be areas where I disagree with his policies or actions. Overall, I believe that he is doing a good job and I approve of his performance in office.",
#     "Answer": "Approve"
# }
# 46 {
#     "Reasoning": "As Regina Long, a conservative with a history of voting for Republican candidates, I am likely to disapprove of President Joe Biden's performance in office. Additionally, my media consumption habits suggest that I consume conservative news outlets that may portray Biden's policies and actions in a negative light. However, as a retail sales associate with less than a high school education, I may not have a deep understanding of the intricacies of politics and policy-making. Therefore, my opinion may be more influenced by my political affiliation and media consumption than by a nuanced understanding of Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# 45 {
#     "Reasoning": "As Erica Murphy, a conservative individual who aligns herself with the Republican Party, I am likely to disapprove of President Joe Biden's performance in office. I believe in smaller government, lower taxes, and individual freedoms, which are not necessarily aligned with the policies and actions of the current administration. Additionally, as a consumer of conservative media outlets, I am likely to be exposed to negative coverage of President Biden and his policies, which may further influence my opinion. However, it is important to note that my personal beliefs and media consumption habits may not be representative of all individuals in my demographic or geographic location.",
#     "Answer": "Disapprove"
# }
# 47 {
#     "Reasoning": "As Daisy Sanchez, I tend to align myself with the Republican Party and conservative values. Therefore, I am likely to disapprove of President Joe Biden's performance in office. Additionally, I consume media outlets that cater to conservative values and interests, which may further reinforce my disapproval of his performance. However, I also believe in researching each candidate and their policies before making a decision. Therefore, I would need to review President Biden's policies and actions in office before making a final decision on whether to approve or disapprove of his performance.",
#     "Answer": "Disapprove"
# }
# 51 {
#     "Reasoning": "As Tiva Whale, a right-leaning individual, I am likely to disapprove of President Joe Biden's performance in office. I may disagree with his policies and his approach to governing. Additionally, I may not trust the media outlets that are reporting on his performance, as they may have a left-leaning bias. However, I also recognize that I may not have all the information necessary to make an informed decision about his performance, and that my personal biases may be influencing my opinion.",
#     "Answer": "Disapprove"
# }
# 50 {
#     "Reasoning": "As Viola Sanders, I am a liberal and likely to support candidates who align with my political beliefs and values. Joe Biden is a Democrat and has a history of supporting policies that align with liberal values. Additionally, as a retail sales associate with an income of $32,200, I may benefit from policies such as a higher minimum wage and expanded access to healthcare, which are priorities for the Biden administration. Therefore, I approve of President Joe Biden's performance in office so far.",
#     "Answer": "Approve"
# }
# 48 {
#     "Reasoning": "As Joyce Garcia, a conservative individual who prioritizes limited government, individual freedoms, and a strong national defense, I am likely to disapprove of President Joe Biden's performance in office. Based on my media consumption and voting history, I am more likely to trust and consume media outlets that cater to conservative values and interests. Therefore, I am more likely to be exposed to negative coverage of President Biden's policies and actions. Additionally, I prioritize candidates who align with my conservative values and beliefs, and President Biden's policies may not align with my beliefs. However, I also take the time to research each candidate's stance on various issues before making a decision. Therefore, I will consider any positive actions or policies that President Biden has implemented since taking office.",
#     "Answer": "Disapprove"
# }
# 53 {
#     "Reasoning": "As William Gonzales, a conservative individual who values smaller government and individual freedoms, I am likely to disapprove of President Joe Biden's performance in office. Based on my media consumption and influential figures, I am likely to consume media outlets that are critical of President Biden's policies and actions. Additionally, my voting history suggests that I tend to vote for conservative candidates who align with my political beliefs and values. Therefore, I am likely to disapprove of President Biden's performance in office due to policy disagreements and ideological differences.",
#
#     "Answer": "Disapprove"
# }
# 49 {
#     "Reasoning": "As Sefu Bobcat, I tend to align myself with the Republican Party and conservative values. Therefore, I am more likely to disapprove of President Joe Biden's performance in office. Additionally, I consume media outlets that cater to conservative audiences, which may have a negative bias towards President Biden. However, I also believe in researching and understanding the policies and actions of our leaders before making a decision. Therefore, I would need to review President Biden's policies and actions in office before making a final decision on whether to approve or disapprove of his performance.",
#
#     "Answer": "Disapprove"
# }
# 52 {
#     "Reasoning": "As a moderate with no particular political affiliation, I would base my opinion of President Joe Biden's performance in office on his actions and policies rather than his party affiliation. I would consume media from a variety of sources to stay informed about his actions and policies. Based on my personal beliefs and values, I would evaluate his performance in areas such as healthcare, education, climate change, and social justice. I would also consider his ability to work with members of both parties to address important issues facing our country. Overall, I would make my decision based on the issues and his actions rather than his party affiliation.",
#     "Answer": "Approve"
# }
# 54 {
#     "Reasoning": "As Edith Brown, a right-leaning individual, I tend to support policies and politicians that align with my political beliefs. However, I also evaluate each candidate's platform and track record before making a decision. While I may not agree with all of President Biden's policies, I believe that it is important to give him a chance to implement his agenda and evaluate his performance over time. Additionally, as a real estate agent, I am interested in policies that promote economic growth and job creation, which are priorities for the Biden administration. Based on these factors, I approve of President Biden's performance in office at this point in time.",
#     "Answer": "Approve"
# }
# 56 {
#     "Reasoning": "As Lorraine Davis, I consider myself a moderate and tend to vote for candidates who I believe will best represent my values and interests, regardless of their party affiliation. While I may not agree with all of President Biden's policies, I believe that he is making an effort to address important issues such as the COVID-19 pandemic, climate change, and economic recovery. Additionally, as a marketing manager, I may be interested in media that covers business and industry news, and I have seen positive reports on the state of the economy under President Biden's administration. Therefore, I approve of President Joe Biden's performance in office at this point in time.",
#     "Answer": "Approve"
# }
# 55 {
#     "Reasoning": "As Bridget Kelly, a right-leaning individual, I am likely to have some skepticism towards President Joe Biden's policies and actions. However, as a young person who is still learning about the political landscape, I am open to considering a wide range of perspectives and viewpoints. I would need to research and analyze President Biden's policies and actions in order to form a well-informed opinion. Additionally, as I have not yet had the opportunity to vote in any elections, I do not have a strong political affiliation or loyalty to any particular party or candidate. Therefore, I am open to considering both positive and negative aspects of President Biden's performance in office before making a decision.",
#     "Answer": "Neither Approve/Disapprove"
# }
# 57 {
#     "Reasoning": "As Connor Thomas, a right-leaning individual, I tend to have a negative view of President Joe Biden's policies and actions. I disagree with many of his decisions, such as his handling of the border crisis and his proposed tax increases. Additionally, I am concerned about the potential for increased government regulation and spending under his administration. However, as an informed voter, I believe it is important to evaluate the President's performance based on his actions and accomplishments. While I may not agree with all of his policies, I acknowledge that he has made progress on issues such as COVID-19 vaccination distribution and infrastructure reform. Overall, I believe that my disapproval of President Biden's policies outweighs any approval I may have for his accomplishments.",
#     "Answer": "Disapprove"
# }
# 60 {
#     "Reasoning": "As Martha Rogers, a conservative individual, I tend to disagree with many of President Joe Biden's policies and actions. Based on my political affiliation and media consumption, I am likely to consume news outlets that are critical of President Biden's performance. Additionally, I tend to vote for candidates who align with my conservative values and beliefs, which may not align with President Biden's policies. Therefore, I would disapprove of President Joe Biden's performance in office at this point in time.",
#     "Answer": "Disapprove"
# }
# 58 {
#     "Reasoning": "As a liberal, Paul Rodriguez is likely to approve of President Joe Biden's performance in office. He may support Biden's policies on issues such as healthcare, climate change, and social justice. Additionally, Paul has a history of consistently voting for candidates who align with his political beliefs, so it is likely that he would support the current Democratic president. However, it is important to note that Paul may also take the time to research and evaluate Biden's specific policies and actions before making a final decision on his approval or disapproval.",
#     "Answer": "Approve"
# }
# 62 {
#     "Reasoning": "As Frances Howard, a liberal resident of rural Montana, I tend to support candidates who align with my political views and values. Joe Biden is a Democrat and has implemented policies that align with my beliefs, such as addressing climate change and promoting social justice. Additionally, I appreciate his efforts to address the COVID-19 pandemic and provide economic relief to those in need. While I may not agree with all of his policies, overall I approve of his performance in office thus far.",
#     "Answer": "Approve"
# }
# 59 {
#     "Reasoning": "As Kristine Bailey, I am a conservative with a political affiliation that aligns with the Republican party. Therefore, I am likely to disapprove of President Joe Biden's performance in office. Additionally, I have great admiration and respect for former President Ronald Reagan, who was also a Republican. Based on my political beliefs and values, I am likely to disagree with many of President Biden's policies and decisions. However, as a retired teacher with a Bachelor's degree or higher, I also value education and intellectual stimulation. Therefore, I may take the time to research and analyze President Biden's policies before making a final decision on his performance in office.",
#     "Answer": "Disapprove"
# }
# 64 {
#     "Reasoning": "As Jeremy Morris, I am a conservative and likely to have a negative view of President Joe Biden's policies and performance in office. I may disagree with his stance on issues such as gun control, immigration, and taxes. Additionally, as a construction worker, I may be concerned about the impact of his policies on the economy and job opportunities. However, since I have not had the opportunity to vote in any elections yet, I may not have a strong opinion on his performance in office so far.",
#     "Answer": "Disapprove"
# }
# 61 {
#     "Reasoning": "As Gregory Patterson, I am a conservative and have historically aligned with the Republican Party. Based on my political affiliation, I am likely to disapprove of President Joe Biden's performance in office. Additionally, I consume media outlets that align with my conservative values, which may provide a biased view of the President's actions and policies. However, I also believe in researching and understanding the candidates and their policies before casting my vote. As a retired farmer, I am concerned about the impact of government policies on the agricultural industry and the economy as a whole. Therefore, I will carefully consider the President's actions and policies before making a final decision on whether to approve or disapprove of his performance in office.",
#     "Answer": "Neither Approve/Disapprove"
# }
# 63 {
#     "Reasoning": "As Doris Howard, a liberal who values equal rights, access to affordable healthcare, and protecting the environment, I approve of President Joe Biden's performance in office. He has taken steps to address these issues, such as signing the American Rescue Plan Act to provide economic relief during the COVID-19 pandemic, expanding access to healthcare, and rejoining the Paris Climate Agreement. Additionally, as someone who values being an informed voter and making decisions based on facts, I appreciate President Biden's commitment to science and evidence-based policies. While there may be areas where I disagree with his policies, overall I believe he is working towards creating a more just and equitable society.",
#     "Answer": "Approve"
# }
# 66 {
#     "Reasoning": "As Raymond Griffin, a left-leaning individual, I am likely to approve of President Joe Biden's performance in office. I prioritize issues such as healthcare and workers' rights, which align with Biden's policies. Additionally, I tend to vote for candidates who align with my political views, and I voted for Biden in the last election. However, I also take the time to research each candidate and their policies before making a decision. Based on my research and the policies that Biden has implemented so far, I believe that he is doing a good job as president.",
#     "Answer": "Approve"
# }
# 65 {
#     "Reasoning": "As Cynthia Adams, I tend to vote for candidates who align with my left-leaning political affiliation and prioritize issues such as education, healthcare, and social justice. President Joe Biden's platform aligns with my values and priorities, and I have been generally pleased with his performance in office so far. He has taken steps to address issues such as the COVID-19 pandemic, climate change, and social justice, which are all important to me. Additionally, as a retired educator, I appreciate his focus on education and his efforts to increase funding for schools and support for teachers. Based on this, I approve of President Joe Biden's performance in office at this point in time.",
#     "Answer": "Approve"
# }
# 67 {
#     "Reasoning": "As a conservative, Jamie is likely to have a negative view of President Joe Biden's performance in office. Additionally, her media consumption is likely to include conservative news outlets that may portray a negative image of the President. Her voting history also suggests that she tends to vote for candidates who align with her political beliefs and values, regardless of their party affiliation. Therefore, it is likely that Jamie disapproves of President Joe Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# 69 {
# ...
#     "Answer": "Disapprove"
# }
# 78 {
#     "Reasoning": "As a conservative, it is likely that Isaac Rivera may not approve of President Joe Biden's performance in office. However, it is important to note that Isaac is a veteran outreach coordinator and may have a more nuanced view on certain policies related to veterans. Additionally, while Isaac is a conservative, he does not blindly vote along party lines and considers each candidate's individual platform and values before making a decision. Therefore, it is possible that Isaac may approve of certain policies or actions taken by President Biden, even if he does not agree with his overall political ideology.",
#     "Answer": "Disapprove"
# }
# 81 {
#     "Reasoning": "As Marianne Jones, a conservative voter, I disapprove of President Joe Biden's performance in office. I do not agree with his policies and believe that they are harmful to the country. I also do not agree with his approach to governing, which I believe is too liberal and not in line with conservative values. Additionally, I have always supported the Republican Party and have voted for conservative candidates in the past, so it is unlikely that I would approve of a Democratic president's performance in office.",
#     "Answer": "Disapprove"
# }
# 80 {
#     "Reasoning": "As Koko Six, a conservative rancher living in rural Montana, I tend to lean towards conservative political views. Based on my political affiliation and media consumption, I am likely to consume news outlets that are critical of President Joe Biden's policies and actions. However, as a responsible citizen, I believe in giving credit where it is due. Therefore, I would evaluate President Biden's performance based on his policies and actions that align with my values and beliefs. I would also consider his performance in addressing issues that are important to me as a rancher living in rural Montana, such as agriculture, rural development, and individual freedom. Based on my evaluation, I would decide whether to approve or disapprove of his performance in office.",
#     "Answer": "Disapprove"
# }
# 82 {
#     "Reasoning": "As Robert Collins, a conservative construction worker who consumes media outlets that align with my political affiliation, I am likely to disapprove of President Joe Biden's performance in office. I tend to support smaller government and lower taxes, which are not priorities of the current administration. Additionally, I may disagree with some of the policies and actions taken by President Biden and his administration. However, I also believe in being an informed voter and considering each candidate's policies and actions before making a decision. Based on my personal beliefs and values, I have come to the conclusion that I disapprove of President Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# 87 {
#     "Reasoning": "As Wohali South, a right-leaning individual who tends to vote based on policies and not party lines, I would evaluate President Joe Biden's performance based on his policies and actions. I would consider his policies related to the environment, marginalized communities, and healthcare, which are issues that are important to me. Additionally, I would consider his ability to work across party lines and his efforts to address issues like climate change and inequality. Based on my evaluation, I would approve of President Joe Biden's performance in office so far.",
#     "Answer": "Approve"
# }
# 86 {
#     "Reasoning": "As Colin Lopez, a moderate with no disclosed political affiliation, I believe that it is important to evaluate a president's performance based on their actions and policies rather than their party affiliation. While I may not agree with all of President Biden's policies, I believe that he has shown a willingness to work towards addressing important issues such as healthcare, economic inequality, and climate change. Additionally, I appreciate his efforts to promote unity and civility in our political discourse. Therefore, I approve of President Joe Biden's performance in office at this point in time.",
#
#     "Answer": "Approve"
# }
# 85 {
#     "Reasoning": "As Madison Perez, a moderate voter, I believe in making informed decisions based on the issues and the candidate's qualifications. While I may not agree with all of President Biden's policies, I believe that he has shown a willingness to work towards bipartisanship and has taken steps to address important issues such as healthcare and climate change. Additionally, as a veteran, I appreciate his commitment to supporting our military and their families. Based on these factors, I approve of President Joe Biden's performance in office at this point in time.",
#
#     "Answer": "Approve"
# }
# 84 {
#     "Reasoning": "As Benjamin Cox, a conservative individual who tends to vote for Republican candidates, I am likely to disapprove of President Joe Biden's performance in office. I believe in smaller government, lower taxes, and individual freedoms, which are not necessarily aligned with the policies and positions of the Democratic Party. Additionally, based on my media consumption habits, I am likely to consume media outlets that are critical of President Biden and his policies. However, as an individual who believes in researching and understanding the candidates and their policies before casting my vote, I would need to evaluate President Biden's specific actions and decisions in office before making a final determination on whether I approve or disapprove of his performance.",
#     "Answer": "Disapprove"
# }
# 88 {
#     "Reasoning": "As a moderate political affiliate, Evan Henderson is likely to evaluate President Joe Biden's performance based on his policies and actions rather than his political party affiliation. Given his interest in economic development and healthcare access, he may evaluate Biden's performance based on his policies related to these issues. Additionally, as a retired farmer living in rural Montana, he may be interested in Biden's policies related to agriculture and environmental protection. Based on his voting history, he is likely to have participated in the recent presidential election and may have voted for Biden. Therefore, he is likely to approve of President Joe Biden's performance in office at this point in time.",
#     "Answer": "Approve"
# }
# 89 {
#     "Reasoning": "As Joshua Moore, I tend to vote for candidates who align with my left-leaning political views and who I believe will work towards policies that benefit the working class and those in need. Based on my political affiliation, I am more likely to approve of President Joe Biden's performance in office as he has taken steps towards implementing policies that align with my beliefs, such as increasing access to healthcare and education, and addressing climate change. Additionally, I value a candidate's character, experience, and track record, and I believe that President Biden has demonstrated these qualities throughout his career. However, I also acknowledge that no candidate is perfect and there may be areas where I disagree with his policies or decisions.",
#     "Answer": "Approve"
# }
# 91 {
#     "Reasoning": "As Isaac Smith, I am a conservative and have always supported the Republican Party. Based on my political affiliation, I am likely to disapprove of President Joe Biden's performance in office. Additionally, I have always believed in smaller government and lower taxes, which are not values that align with the current administration's policies. However, as a retired rancher, I am also concerned about issues affecting the agriculture industry, such as trade policies and environmental regulations. I would need to research more about the current administration's policies on these issues before making a final decision.",
#     "Answer": "Disapprove"
# }
# 90 {
#     "Reasoning": "As Alexander Baker, a conservative individual who prioritizes smaller government, lower taxes, and a strong national defense, I am likely to disapprove of President Joe Biden's performance in office. President Biden's policies and actions, such as his proposed tax increases and his handling of the Afghanistan withdrawal, do not align with my political beliefs and priorities. Additionally, as someone who regularly consumes conservative media outlets, I am likely to be exposed to negative coverage of President Biden's actions and decisions. However, it is important to note that my disapproval of President Biden's performance is based on my political beliefs and priorities, and may not necessarily reflect the opinions of others.",
#     "Answer": "Disapprove"
# }
# 92 {
#     "Reasoning": "As Michael Baker, a conservative individual who consumes media from outlets such as Fox News and Breitbart, I am likely to disapprove of President Joe Biden's performance in office. Additionally, I have not voted for him in the past and plan to vote for conservative candidates in the future. I may also be concerned about his policies and their potential impact on the economy and national security. However, as a supermarket cashier, I may not have a deep understanding of political issues and may not be closely following the news. Therefore, I may not have a strong opinion on his performance in office.",
#     "Answer": "Disapprove"
# }
# 93 {
#     "Reasoning": "As Lee Moore, a liberal and member of the Democratic Party, I am likely to approve of President Joe Biden's performance in office. I may have voted for him in the past election and support his policies and initiatives, such as his efforts to combat climate change, expand healthcare access, and promote social justice. Additionally, as a veteran affairs coordinator, I may support his plans to improve healthcare and benefits for veterans. However, I also acknowledge that not everyone may share my political views and that there may be valid criticisms of his performance so far.",
#     "Answer": "Approve"
# }
# 95 {
#     "Reasoning": "As Gabriel Davis, I tend to lean towards a right-leaning political affiliation and prioritize individual freedom and limited government. Based on my political beliefs, I am likely to disapprove of President Joe Biden's performance in office. Additionally, I may consume media outlets that are critical of his policies and actions, which may further reinforce my disapproval. However, as an individual who takes the time to research each candidate and their positions before making a decision, I may also consider specific policies or actions that I approve of, even if I overall disapprove of his performance in office.",
#     "Answer": "Disapprove"
# }
# 94 {
#     "Reasoning": "As Garrett Griffin, a moderate construction worker from rural Montana, I have voted for candidates from both major parties depending on their policies and positions. Therefore, I would evaluate President Joe Biden's performance based on his policies and actions rather than his party affiliation. As a moderate, I am likely to have a balanced view of his performance and consider both the positive and negative aspects. I would also consider the impact of his policies on my community and the country as a whole. Based on my media consumption, I may have been exposed to both conservative and mainstream media outlets, which may have influenced my opinion. Overall, I would evaluate President Joe Biden's performance based on his policies and actions rather than his party affiliation.",
#     "Answer": "Neither Approve/Disapprove"
# }
# 97 {
#     "Reasoning": "As Alexander Phillips, I tend to prioritize candidates who align with my right-leaning political affiliation and share my values and beliefs. However, I also believe in giving credit where it is due. President Joe Biden has only been in office for a short period of time, and while I may not agree with all of his policies, I believe it is too early to make a definitive judgement on his performance. Additionally, as a retired farmer, I am interested in policies that benefit the agriculture industry, and I am hopeful that President Biden will prioritize this sector. Overall, I am neither approving nor disapproving of President Joe Biden's performance in office at this point in time.",
#     "Answer": "Neither Approve/Disapprove"
# }
# 96 {
#     "Reasoning": "As Sally Adams, I tend to align with liberal political views and prioritize environmental issues. Based on my political affiliation and values, I approve of President Joe Biden's performance in office so far. He has taken steps to address climate change and environmental protection, such as rejoining the Paris Climate Agreement and proposing a $2 trillion infrastructure plan that includes investments in clean energy. Additionally, he has made efforts to address social justice issues, such as signing executive orders to promote racial equity and ending the ban on transgender individuals serving in the military. While there is still much work to be done, I believe that President Biden is moving in the right direction and taking steps to address the urgent issues facing our country and the world.",
#     "Answer": "Approve"
# }
# Error communicating with OpenAI: That model is currently overloaded with other requests. You can retry your request, or contact us through our help center at help.openai.com if the error persists. (Please include the request ID 08b5ef11f04f623edc0752b25aa7d78c in your message.)
# 98 {
#     "Reasoning": "As Marie Thompson, a conservative individual who tends to vote for Republican candidates, I am likely to disapprove of President Joe Biden's performance in office. I may disagree with his policies and actions, particularly those related to taxes, government regulation, and individual freedoms. Additionally, as someone who consumes conservative media outlets, I may be exposed to negative coverage of President Biden and his administration. However, I also believe in researching and understanding the policies and actions of elected officials before forming an opinion. Therefore, I would need to review President Biden's policies and actions in more detail before making a final decision on whether to approve or disapprove of his performance in office.",
#     "Answer": "Disapprove"
# }
# 99 {
#     "Reasoning": "As Kathryn Cox, a conservative individual living in rural Montana, I tend to support candidates who align with my political beliefs and values. President Joe Biden, being a Democrat, may not align with my political beliefs and values. However, I also believe in researching each candidate and their policies before making a decision. Based on my media consumption and voting history, I am likely to consume media outlets that align with my conservative political affiliation. Therefore, I may have limited exposure to media outlets that provide a more balanced view of President Biden's performance in office. However, as a responsible citizen, I believe in giving credit where it is due. Therefore, I would like to evaluate President Biden's performance in office based on his policies and actions rather than his political affiliation.",
#     "Answer": "Neither Approve/Disapprove"
# }
# 83 {
#     "Reasoning": "As a conservative with a history of voting for conservative candidates, it is likely that Dylan Rogers would disapprove of President Joe Biden's performance in office. Additionally, based on his media consumption, Dylan is likely to consume news outlets that are critical of President Biden and his policies. However, it is important to note that Dylan's personal anecdotes suggest that he values individual freedoms and limited government intervention in the economy, which may align with some of President Biden's policies. Ultimately, based on his political affiliation and media consumption, it is likely that Dylan would disapprove of President Biden's performance in office.",
#     "Answer": "Disapprove"
# }
# Total Prompt Tokens: 118851
# Total Completion Tokens: 13553
#
# Token Cost = $ 0.264808

# %%
answers2 = []
for resp in responses_2:
    data = json.loads(resp)
    answers2.append(data['Answer'])
    
disapprove_count, approve_count, neither_count = count_answers(answers2)
print("Disapprove count:", disapprove_count)
print("Approve count:", approve_count)
print("Neither count:", neither_count)
# Out:
# Disapprove count: 52
# Approve count: 36
# Neither count: 12

# %%
responses_3 = []
#question = "Do you plan to vote in the 2024 midterm election?\n Yes\n No\n Undecided\n Please note, you are allowed to say no and not voted"

question = "Do you agree or disagree that there is a mental health crisis in Montana?\nAgree\nDisagree\nNeither Agree/Disagree"

#question = "Do you approve or disapprove of President Joe Biden's student loan forgiveness plan?\nApprove\nDisapprove\nNeither Approve/Disapprove"

total_prompt_tokens = 0
total_completion_tokens = 0


def thread_func(i):
    global total_prompt_tokens, total_completion_tokens
    persona_role = GPT.open_file(f"Prompts/Polling/persona_role.txt").replace('<<PERSONA>>', str(personas[i]))
    question_in = GPT.open_file("Prompts/Polling/question_in.txt").replace('<<QUESTION>>', question)
    #print(persona_role, question_in)
    resp, usage = GPT.chat_gpt(question_in, engine = 'gpt-3.5-turbo' , role = persona_role, temp = 0.1, tokens = 300)
    total_completion_tokens += usage['completion_tokens']
    total_prompt_tokens += usage['prompt_tokens']
    print(i, resp)
    return resp

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    responses_3 = list(executor.map(thread_func, range(len(personas))))

print("Total Prompt Tokens:", total_prompt_tokens)
print("Total Completion Tokens:", total_completion_tokens)
print()
print("Token Cost = $", str((total_prompt_tokens+total_completion_tokens)/1000*0.002))
# Out:
# 3 {
#     "Reasoning": "As a retired business owner living in urban Montana, I have seen the effects of mental health issues on individuals and the community. I am aware that Montana has one of the highest suicide rates in the country, and I believe that this is indicative of a larger mental health crisis. Additionally, I have seen firsthand how the lack of access to mental health resources can impact individuals and their families. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 7 {
#     "Reasoning": "As Charlotte Harris, I agree that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware that mental health resources and services are limited in rural areas like where I live. Additionally, the COVID-19 pandemic has had a significant impact on mental health, with many people experiencing increased stress, anxiety, and depression. I believe that addressing the mental health crisis is important for the well-being of individuals and the overall health of our communities.",
#     "Answer": "Agree"
# }
# 9 {
#     "Reasoning": "As Lisha Patterson, I agree that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware of the high rates of suicide and substance abuse in Montana, particularly among young people. Additionally, as a retired educator, I have seen firsthand the impact of mental health issues on students and their families. I believe that access to mental health care is important for individuals to lead healthy and productive lives, and that there is a need for more resources and support for those struggling with mental health issues.",
#     "Answer": "Agree"
# }
# 2 {
#     "Reasoning": "As Sean Foster, I believe that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the high rates of suicide and substance abuse in rural areas like Montana. Additionally, as an oil rig worker, I may have limited access to mental health resources and support. I also believe that there is a stigma surrounding mental health in rural areas, which may prevent individuals from seeking help. Overall, I think that addressing the mental health crisis in Montana is an important issue that requires attention and resources.",
#     "Answer": "Agree"
# }
# 8 {
#     "Reasoning": "As Jeffrey Baker, I am an accountant living in urban Montana. While I do not have any personal anecdotes related to mental health, I am aware that mental health is a growing concern in the United States. Additionally, Montana has a high suicide rate, which may be an indicator of a mental health crisis. As a conservative, I believe in personal responsibility and self-sufficiency, but I also recognize the importance of access to mental health resources for those who need it. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 5 {
#     "Reasoning": "As Mae Foster, I agree that there is a mental health crisis in Montana. Although I do not have any personal anecdotes related to mental health, I am aware of the challenges that rural communities face in accessing mental health services. Montana has a high suicide rate, and I believe that this is indicative of a larger mental health crisis. Additionally, as an Agricultural Extension Agent, I am aware of the stress and mental health challenges that farmers and ranchers face. The isolation and financial pressures of the agricultural industry can contribute to mental health issues. Therefore, I believe that there is a mental health crisis in Montana that needs to be addressed.",
#     "Answer": "Agree"
# }
# 0 {
#     "Reasoning": "As Imogen Bailey, a 27-year-old marketing coordinator living in urban Montana, I am likely to have some awareness of the mental health situation in my state. Montana has a high suicide rate, and mental health resources can be limited in rural areas. As someone who is moderately politically affiliated, I might be aware of the political debates around mental health funding and access to care. Additionally, as someone who consumes news from reputable sources like CNN and The New York Times, I am likely to have come across articles discussing the mental health crisis in Montana. Based on this information, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 6 {
#     "Reasoning": "As Tyler King, I agree that there is a mental health crisis in Montana. While I do not have any personal anecdotes related to mental health, I am aware of the high rates of suicide and substance abuse in Montana, which are often linked to mental health issues. Additionally, as a construction worker, I have seen firsthand the toll that physical labor can take on one's mental health, especially when combined with financial stress and other life challenges. Furthermore, I am aware that Montana has a shortage of mental health professionals and resources, which can exacerbate the crisis. Overall, based on my knowledge and understanding of the situation, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 1 {
#     "Reasoning": "As Tyler Patterson, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that many people in rural areas like mine may not have access to adequate mental health resources. Additionally, the isolation and lack of community support in rural areas can exacerbate mental health issues. I have also seen news coverage and heard stories from others about the high suicide rates in Montana, which is a clear indication of a mental health crisis. Therefore, based on the information available to me, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 4 {
#     "Reasoning": "As Richard Hernandez, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that mental health resources and services are limited in rural areas like mine. Additionally, the COVID-19 pandemic has had a significant impact on mental health, with increased stress, anxiety, and depression affecting many people. I believe that it is important for our community and our state to prioritize mental health resources and support for those who need it.",
#     "Answer": "Agree"
# }
# 11 {
#     "Reasoning": "As Hunter Young, I believe that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the high rates of suicide in Montana and the lack of resources available for those struggling with mental health. Additionally, as a construction worker, I may have colleagues who are struggling with mental health issues due to the physically demanding and often dangerous nature of the job. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 14 {
#     "Reasoning": "As Miguel Ortiz, I agree that there is a mental health crisis in Montana. Although I am a construction worker and may not have direct experience with mental health issues, I am aware that mental health is a serious issue that affects many people. Additionally, Montana is a rural state with limited access to mental health resources, which can exacerbate the problem. I believe that mental health is just as important as physical health, and that we need to do more as a society to address this issue.",
#     "Answer": "Agree"
# }
# 10 {
#     "Reasoning": "As Stacy Johnson, I believe that there is a mental health crisis in Montana. Although I do not have any personal anecdotes related to this issue, I am aware that Montana has a high suicide rate and limited access to mental health resources, particularly in rural areas. Additionally, as a marketing coordinator, I am familiar with the impact of stress and mental health on individuals in the workplace. Therefore, I believe that it is important to address the mental health crisis in Montana and provide individuals with the resources and support they need to maintain their mental well-being.",
#     "Answer": "Agree"
# }
# 12 {
#     "Reasoning": "As Grace Davis, I agree that there is a mental health crisis in Montana. While I do not have personal anecdotes related to this issue, I am aware of the high rates of suicide and substance abuse in Montana, particularly in rural areas. Additionally, I know that access to mental health services can be limited in Montana due to factors such as geographic location and lack of healthcare providers. As someone who believes in social justice and access to healthcare, I believe that addressing the mental health crisis in Montana is an important issue that requires attention and resources.",
#     "Answer": "Agree"
# }
# 17 {
#     "Reasoning": "As Rosa Juarez, I am not sure if there is a mental health crisis in Montana. However, as a resident of a rural area, I know that access to mental health resources can be limited. Additionally, as someone with a lower income and education level, I know that mental health issues can be stigmatized and not always taken seriously. Therefore, I am inclined to agree that there may be a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 13 {
#     "Reasoning": "As Felicity Ross, I agree that there is a mental health crisis in Montana. While I do not have any personal anecdotes related to this issue, I am aware that mental health is a growing concern in the United States. Additionally, as a retail sales associate, I interact with a variety of people on a daily basis and have seen firsthand the effects of stress and anxiety on individuals. Furthermore, Montana is a rural state with limited access to mental health resources, which can exacerbate the crisis. Therefore, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 15 {
#     "Reasoning": "As Evan Carter, I am not an expert on mental health, but I do believe that mental health is an important issue that affects many people. While I do not have specific information about mental health in Montana, I know that mental health issues are prevalent across the country. Additionally, as a software engineer, I am aware of the potential impact of stress and long work hours on mental health. Therefore, I believe that there is likely a mental health crisis in Montana, as there is in many other parts of the country.",
#     "Answer": "Agree"
# }
# 18 {
#     "Reasoning": "As an 85-year-old retired business executive living in urban Montana, Alexander Harris may have limited exposure to mental health issues in the state. However, he may be aware of the growing concern around mental health in the country and the impact it has on individuals and communities. Additionally, as someone who values access to quality healthcare and education, he may recognize the importance of addressing mental health issues in the state. Therefore, he is likely to agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 16 {
#     "Reasoning": "As Justin Lopez, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the challenges that rural communities face in accessing mental health services. Montana has a high suicide rate, and many individuals in rural areas may not have access to mental health professionals or resources. Additionally, the COVID-19 pandemic has exacerbated mental health issues for many individuals, including farmers and ranchers who may be struggling with financial stress and isolation. Overall, I believe that there is a need for increased access to mental health services and resources in Montana.",
#     "Answer": "Agree"
# }
# 19 {
#     "Reasoning": "As a retired military veteran, Walter Watson may have seen or experienced mental health issues among his fellow service members. Additionally, living in a rural area may limit access to mental health resources, which could contribute to a mental health crisis. However, without more information about the specific mental health statistics in Montana, it is difficult to make a definitive statement. Overall, given the potential factors at play, Walter is likely to agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 20 {
#     "Reasoning": "As Joyce Ward, I agree that there is a mental health crisis in Montana. Although I do not have any personal experiences with mental health issues, I am aware that mental health services in rural areas, such as where I live, can be limited and difficult to access. Additionally, I have read news articles and heard stories from others about the high rates of suicide and depression in Montana. I believe that it is important for our state and local governments to prioritize mental health services and resources to address this crisis.",
#     "Answer": "Agree"
# }
# 21 {
#     "Reasoning": "As Diane Myers, a veteran affairs officer, I have seen firsthand the impact that mental health issues can have on individuals, especially veterans. Montana has a high population of veterans, and I have seen many struggle with mental health issues such as PTSD. Additionally, living in a rural area can make it difficult for individuals to access mental health resources. Based on my experiences and observations, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 28 {
#     "Reasoning": "As a retired teacher from rural Montana, I have seen firsthand the impact of mental health issues on individuals and communities. Montana has a high suicide rate, and I believe that mental health is a serious issue that needs to be addressed. Additionally, as someone who values individual freedom, I believe that access to mental health care is essential for individuals to live healthy and fulfilling lives. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 22 {
#     "Reasoning": "As Patsy Martinez, I believe that there is a mental health crisis in Montana. While I do not have any personal anecdotes related to this issue, I am aware of the high rates of suicide and substance abuse in Montana, which are often linked to mental health issues. Additionally, as a retired receptionist, I may have interacted with individuals who have struggled with mental health issues. I also consume local news outlets, which may have covered stories related to mental health in Montana. Therefore, based on the information available to me, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 29 {
#     "Reasoning": "As Ian Perry, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that mental health resources can be limited in rural areas like mine. Additionally, I have seen firsthand the impact that economic hardship and other stressors can have on mental health. I believe that it is important for our community to prioritize mental health resources and support for those who may be struggling.",
#     "Answer": "Agree"
# }
# 27 {
#     "Reasoning": "As Shannon Garcia, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the impact that mental health can have on individuals and communities. Additionally, as a retail store manager, I have seen firsthand the effects of stress and anxiety on my employees and customers. I also know that Montana has a shortage of mental health professionals and resources, which can make it difficult for individuals to access the care they need. Overall, I believe that addressing the mental health crisis in Montana is an important issue that requires attention and action.",
#     "Answer": "Agree"
# }
# 26 {
#     "Reasoning": "As Justin Martin, I agree that there is a mental health crisis in Montana. Although I may not have personal experience with mental health issues, I am aware that many individuals in my community may be struggling with mental health challenges. Additionally, as someone with a lower income and less than a high school education, I may be more likely to experience stress and other mental health challenges due to financial and social pressures. Furthermore, I may have limited access to mental health resources and support, which can exacerbate mental health issues. Therefore, I believe that there is a mental health crisis in Montana that needs to be addressed.",
#     "Answer": "Agree"
# }
# 23 {
#     "Reasoning": "As Maggie Jones, I agree that there is a mental health crisis in Montana. While I don't have any personal experience with mental health issues, I know that many people in my community and state struggle with access to mental health services. Montana has a high suicide rate, and I believe that this is in part due to a lack of resources and support for those struggling with mental health issues. Additionally, I know that many people in my community are dealing with the stress and uncertainty of the COVID-19 pandemic, which can exacerbate existing mental health issues or create new ones. Overall, I believe that there is a real need for increased access to mental health services and support in Montana.",
#     "Answer": "Agree"
# }
# 24 {
#     "Reasoning": "As Koa Raccoon, I agree that there is a mental health crisis in Montana. Living in a rural area, I have seen firsthand the lack of access to mental health resources and support for individuals who are struggling with mental health issues. Additionally, as someone who has faced discrimination and marginalization, I understand the impact that systemic issues can have on mental health. Furthermore, my job as a construction worker can be physically and mentally demanding, and I have seen how the lack of support and resources can take a toll on individuals' mental health. Overall, based on my personal experiences and observations, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 25 {
#     "Reasoning": "As Kristine Scott, I agree that there is a mental health crisis in Montana. In my role as a Veteran Outreach Coordinator, I have seen firsthand the impact that mental health issues can have on individuals and communities. Montana has a high suicide rate, and many people in the state struggle with depression, anxiety, and other mental health conditions. Additionally, access to mental health care can be limited in rural areas, which can exacerbate the crisis. While there are efforts underway to address the issue, such as increased funding for mental health services and suicide prevention programs, there is still a long way to go in terms of addressing the root causes of the crisis and providing adequate support for those who are struggling.",
#     "Answer": "Agree"
# }
# 30 {
#     "Reasoning": "As Tracy Mitchell, I agree that there is a mental health crisis in Montana. Although I do not have any personal anecdotes related to mental health, I am aware that Montana has a high suicide rate and limited access to mental health resources. Additionally, as a marketing director, I am aware of the impact that mental health can have on employee productivity and well-being. Therefore, I believe that addressing the mental health crisis in Montana is important for both individual and societal reasons.",
#     "Answer": "Agree"
# }
# 31 {
#     "Reasoning": "As a retired factory worker living in urban Montana, I have seen the impact of mental health issues on individuals and families in my community. I am aware that Montana has one of the highest suicide rates in the country and that access to mental health services can be limited in rural areas. Additionally, I have personal anecdotes of family members and friends who have struggled with mental health issues. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 33 {
#     "Reasoning": "As a retired rancher living in rural Montana, I have limited access to healthcare and mental health resources. I have seen firsthand the impact that this lack of resources can have on individuals and families in my community. Additionally, I am aware of the high suicide rates in Montana, which is a clear indication of a mental health crisis. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 32 {
#     "Reasoning": "As Chelsea Reed, I agree that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware that Montana has a high suicide rate and limited access to mental health resources, particularly in rural areas like where I live. Additionally, the COVID-19 pandemic has likely exacerbated mental health issues for many individuals. Overall, I believe that addressing the mental health crisis in Montana should be a priority for our state and national leaders.",
#     "Answer": "Agree"
# }
# 38 {
#     "Reasoning": "As Caroline Lopez, I agree that there is a mental health crisis in Montana. As a veterinarian, I have seen firsthand the impact that mental health issues can have on both animals and their owners. Additionally, Montana has a high suicide rate, which is often linked to mental health issues. While I may not have personal experience with mental health issues myself, I believe that it is important to acknowledge the crisis and work towards solutions.",
#     "Answer": "Agree"
# }
# 36 {
#     "Reasoning": "As Tabitha Kelly, I agree that there is a mental health crisis in Montana. Living in a rural area, access to mental health resources can be limited. Additionally, economic hardship and limited access to healthcare and education can contribute to mental health issues. I have also seen firsthand the impact of isolation and lack of community support on mental health. Overall, I believe that there is a need for increased access to mental health resources and support in Montana.",
#     "Answer": "Agree"
# }
# 37 {
#     "Reasoning": "As Bradley Henderson, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that mental health resources and support can be limited in rural areas like mine. Additionally, the isolation and stress that can come with living and working in a rural area may contribute to mental health issues. I believe that it is important to prioritize mental health resources and support in Montana, and to work towards reducing the stigma around mental health issues.",
#     "Answer": "Agree"
# }
# 34 {
#     "Reasoning": "As Gertrude Moore, I agree that there is a mental health crisis in Montana. Based on my personal experiences and observations, I have seen how limited access to mental health resources can have a significant impact on individuals and communities. As a rural resident, I know that it can be difficult to access mental health services due to a shortage of providers and limited resources. Additionally, stigma surrounding mental health can prevent individuals from seeking help. I believe that addressing the mental health crisis in Montana is important for the well-being of individuals and the overall health of our communities.",
#     "Answer": "Agree"
# }
# 41 {
#     "Reasoning": "As someone who lives in rural Montana, I have seen firsthand the lack of access to mental health resources and the stigma surrounding mental health issues. Additionally, the isolation and harsh living conditions in rural areas can contribute to mental health struggles. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 35 {
#     "Reasoning": "As Caleb Baker, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that many people in my community struggle with access to mental health care and resources. Additionally, the isolation and lack of social support that can come with living in a rural area like Montana can exacerbate mental health issues. I have also seen firsthand the impact that economic downturns and job loss can have on mental health, as stress and anxiety can lead to depression and other mental health issues. Overall, I believe that addressing the mental health crisis in Montana is an important issue that requires attention and resources.",
#     "Answer": "Agree"
# }
# 40 {
#     "Reasoning": "As Trevor Perez, I agree that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware that Montana has a high suicide rate and limited access to mental health resources. Additionally, as a retail sales associate, I have seen firsthand the impact that stress and anxiety can have on individuals and their mental health. I believe that it is important for our community to prioritize mental health and provide resources and support for those who are struggling.",
#     "Answer": "Agree"
# }
# 39 {
#     "Reasoning": "As Kachina Brown, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the challenges that many individuals in my community face. Montana has a high suicide rate, and I have seen firsthand the impact that mental health issues can have on individuals and families. Additionally, as a rancher, I know that the isolation and stress of rural living can contribute to mental health issues. While there are resources available for those who need help, I believe that more needs to be done to address this crisis.",
#     "Answer": "Agree"
# }
# 43 {
#     "Reasoning": "As Louis Kelly, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the high rates of suicide and substance abuse in Montana, particularly in rural areas like where I live. I also know that access to mental health services can be limited in rural areas, which can exacerbate the problem. Additionally, I believe that the COVID-19 pandemic has only made the mental health crisis worse, as people are dealing with increased stress, isolation, and uncertainty.",
#     "Answer": "Agree"
# }
# 42 {
#     "Reasoning": "As Samuel Romero, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the impact that mental health can have on individuals and communities. As a construction worker, I have seen firsthand the toll that stress and anxiety can take on people in high-pressure jobs. Additionally, I am aware of the lack of resources and support for individuals who may be struggling with mental health issues in Montana. This lack of support can lead to individuals not receiving the care they need, which can have negative consequences for their well-being and the well-being of those around them. Therefore, I believe that there is a mental health crisis in Montana that needs to be addressed.",
#     "Answer": "Agree"
# }
# 44 {
#     "Reasoning": "As Ben Powell, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that mental health is a growing concern in our society. Additionally, as a truck driver, I have seen firsthand the impact that isolation and loneliness can have on individuals, which can contribute to mental health issues. Furthermore, Montana is a rural state with limited access to mental health resources, which can exacerbate the problem. Therefore, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 47 {
#     "Reasoning": "As Daisy Sanchez, I agree that there is a mental health crisis in Montana. Although I do not have personal experience with mental health issues, I am aware that mental health resources in Montana are limited, especially in rural areas. Additionally, the COVID-19 pandemic has caused increased stress and anxiety for many individuals, which may exacerbate existing mental health issues. Furthermore, I believe that mental health is an important aspect of overall health and well-being, and it is important for individuals to have access to resources and support when needed.",
#     "Answer": "Agree"
# }
# 46 {
#     "Reasoning": "As Regina Long, I believe that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware that Montana has a high suicide rate and limited access to mental health resources. Additionally, as someone who works in retail, I have seen firsthand the impact that stress and financial struggles can have on individuals' mental health. While I do not have a solution to this issue, I believe that it is important to acknowledge and address the mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 45 {
#     "Reasoning": "As Erica Murphy, I agree that there is a mental health crisis in Montana. While I do not have any personal anecdotes related to this issue, I am aware that rural areas like mine often have limited access to mental health resources. Additionally, the COVID-19 pandemic has had a significant impact on mental health across the country, and Montana has not been immune to this. As a conservative, I believe in the importance of individual responsibility and self-sufficiency, but I also recognize that mental health issues can be complex and require professional help. Therefore, I believe that it is important for our leaders to prioritize mental health resources and support for those who are struggling.",
#     "Answer": "Agree"
# }
# 48 {
#     "Reasoning": "As Joyce Garcia, I agree that there is a mental health crisis in Montana. Although I do not have any personal anecdotes related to this issue, I am aware that mental health is a growing concern in our society. Additionally, Montana has a high suicide rate, which is often linked to mental health issues. As a retail store manager, I have also seen firsthand the impact of stress and mental health issues on my employees. Therefore, I believe that it is important to address this crisis and provide resources and support for those who are struggling.",
#     "Answer": "Agree"
# }
# 49 {
#     "Reasoning": "As Sefu Bobcat, I believe that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I understand that mental health is an important aspect of overall health and well-being. Additionally, as someone who has experienced economic hardship, I know that access to mental health resources can be limited for those who cannot afford it. Furthermore, living in a rural area may limit access to mental health services, which can exacerbate the crisis. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 50 {
#     "Reasoning": "As Viola Sanders, I agree that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware that many individuals in Montana, particularly in rural areas, may not have access to adequate mental health resources. Additionally, the COVID-19 pandemic has likely exacerbated mental health issues for many individuals. As a liberal, I believe that access to healthcare, including mental healthcare, is a basic human right. Therefore, I believe that it is important to address the mental health crisis in Montana and ensure that all individuals have access to the resources and support they need.",
#     "Answer": "Agree"
# }
# 51 {
#     "Reasoning": "As Tiva Whale, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the challenges that many individuals in my community face when it comes to accessing mental health care. Montana has a high suicide rate, and I believe that this is a reflection of the lack of resources and support for individuals struggling with mental health issues. Additionally, as a construction worker, I have seen firsthand the toll that stress and anxiety can take on individuals in physically demanding jobs. Overall, I believe that there is a need for more resources and support for individuals struggling with mental health issues in Montana.",
#     "Answer": "Agree"
# }
# 56 {
#     "Reasoning": "As Lorraine Davis, I am aware that Montana has a high suicide rate and limited access to mental health resources, particularly in rural areas. Additionally, as someone who values access to healthcare and believes in the importance of addressing mental health issues, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 53 {
#     "Reasoning": "As William Gonzales, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that mental health resources in rural areas like mine can be limited. Additionally, the COVID-19 pandemic has had a significant impact on mental health, with increased stress and isolation affecting many individuals. I believe that it is important for our community to prioritize mental health resources and support for those who may be struggling.",
#     "Answer": "Agree"
# }
# 57 {
#     "Reasoning": "As Connor Thomas, I agree that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware that Montana has a high suicide rate and limited access to mental health resources. Additionally, the COVID-19 pandemic has likely exacerbated mental health issues for many individuals. As a member of the community, I believe it is important to acknowledge and address this crisis in order to support those who may be struggling.",
#     "Answer": "Agree"
# }
# 55 {
#     "Reasoning": "As Bridget Kelly, I am aware of the impact that mental health can have on individuals and communities. While I do not have any personal anecdotes related to mental health, I am aware that Montana has a high suicide rate and limited access to mental health resources, particularly in rural areas. Additionally, the COVID-19 pandemic has had a significant impact on mental health across the country, and Montana is no exception. Based on these factors, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 52 {
#     "Reasoning": "As an 18-year-old retail sales associate from an urban area in Montana, I may not have a comprehensive understanding of the mental health situation in the state. However, based on my personal experiences and what I have heard from others, I believe that there is a mental health crisis in Montana. I have seen friends and family members struggle with mental health issues, and I know that access to mental health resources can be limited in rural areas. Additionally, I have heard about the high suicide rates in Montana, which is a clear indication that there are significant mental health challenges in the state. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 54 {
#     "Reasoning": "As Edith Brown, I agree that there is a mental health crisis in Montana. While I do not have any personal anecdotes related to mental health, I am aware of the challenges that individuals in my community face when it comes to accessing mental health services. Montana has a high suicide rate, and I believe that this is indicative of a larger mental health crisis in the state. Additionally, I am aware that many individuals in rural areas of Montana may not have access to mental health services due to a lack of providers and resources. Overall, I believe that there is a significant need for increased access to mental health services in Montana.",
#     "Answer": "Agree"
# }
# 59 {
#     "Reasoning": "As Kristine Bailey, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the challenges that individuals in rural areas like mine face when it comes to accessing mental health resources. Montana has a shortage of mental health professionals, particularly in rural areas, which can make it difficult for individuals to receive the care they need. Additionally, stigma surrounding mental health can prevent individuals from seeking help. These factors contribute to a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 58 {
#     "Reasoning": "As Paul Rodriguez, I agree that there is a mental health crisis in Montana. Although there is no information provided about the specific mental health statistics in Montana, as an urban resident, I may have access to more mental health resources and information than those living in rural areas. Additionally, my income level as a retail sales associate may limit my access to mental health care, and this may be the case for many others in Montana. Furthermore, the COVID-19 pandemic has had a significant impact on mental health across the country, and Montana is no exception. Therefore, based on these factors, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 62 {
#     "Reasoning": "As Frances Howard, I agree that there is a mental health crisis in Montana. Rural areas like where I live often lack access to mental health resources and services, which can lead to untreated mental health issues. Additionally, the isolation and stress of living in a rural area can exacerbate mental health problems. I have seen firsthand the impact of mental health issues on individuals and families in my community, and I believe that more needs to be done to address this crisis.",
#     "Answer": "Agree"
# }
# 60 {
#     "Reasoning": "As Martha Rogers, I agree that there is a mental health crisis in Montana. Although there is no information provided about Martha's personal experiences with mental health, she is a young professional living in an urban area, which can be a stressful environment. Additionally, Montana has a high suicide rate, which is often linked to mental health issues. As a conservative, Martha may believe that individuals should take personal responsibility for their mental health, but she may also recognize that there are systemic issues that contribute to the mental health crisis, such as lack of access to mental health care and stigma surrounding mental illness.",
#     "Answer": "Agree"
# }
# 63 {
#     "Reasoning": "As Doris Howard, I agree that there is a mental health crisis in Montana. Based on my personal experiences and media consumption, I have seen a growing need for mental health services in my community. Additionally, Montana has a high suicide rate, which is often linked to mental health issues. As an administrative assistant, I have also seen the impact of stress and mental health issues on the workplace. Overall, I believe that there is a significant need for increased access to mental health services and resources in Montana.",
#     "Answer": "Agree"
# }
# 61 {
#     "Reasoning": "As Gregory Patterson, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the challenges that many people in rural areas face in accessing mental health care. Montana has a high suicide rate, and I believe that addressing mental health issues is an important step in reducing that rate. Additionally, as a conservative, I believe in the importance of individual responsibility and self-sufficiency, but I also recognize that mental health issues can be a barrier to achieving those goals. Therefore, I believe that addressing the mental health crisis in Montana is important for both individual well-being and the overall health of our communities.",
#     "Answer": "Agree"
# }
# 67 {
#     "Reasoning": "As a Veteran Outreach Coordinator, I have seen firsthand the mental health challenges that many veterans face when they return home from service. Additionally, living in a rural area like Montana can make it difficult for individuals to access mental health resources. Based on my personal and professional experiences, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 64 {
#     "Reasoning": "As Jeremy Morris, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the challenges that many people in my community face. Living in a rural area, access to mental health resources may be limited, and stigma surrounding mental health may prevent people from seeking help. Additionally, economic struggles and job insecurity can contribute to stress and anxiety, which can exacerbate mental health issues. Overall, I believe that addressing the mental health crisis in Montana is an important issue that requires attention and resources.",
#     "Answer": "Agree"
# }
# 69 {
#     "Reasoning": "As a retired rancher living in urban Montana, I may not have direct experience with mental health issues in the state. However, based on my age and life experience, I may have seen changes in the way mental health is viewed and treated over time. Additionally, I may have seen the impact of economic and social factors on mental health in my community. Based on these factors, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 65 {
#     "Reasoning": "As Cynthia Adams, I agree that there is a mental health crisis in Montana. While I do not have specific data on the mental health situation in Montana, I know that mental health is a critical issue across the country. Additionally, as a retired educator, I have seen firsthand the impact that mental health issues can have on students and their families. I believe that mental health is just as important as physical health, and that it is important to prioritize mental health care and support for those who need it. Given the lack of mental health resources in many areas, including rural areas like Montana, I believe that it is likely that there is a mental health crisis in the state.",
#     "Answer": "Agree"
# }
# 66 {
#     "Reasoning": "As Raymond Griffin, I agree that there is a mental health crisis in Montana. Living in a rural area, access to mental health resources may be limited, and the stigma surrounding mental health may prevent individuals from seeking help. Additionally, as a construction worker, Raymond may have experienced firsthand the toll that a physically demanding job can take on one's mental health. Furthermore, Raymond's personal anecdotes as a veteran may have exposed him to the mental health struggles that many veterans face. Overall, based on his personal experiences and geographic location, Raymond may be more likely to recognize the mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 68 {
#     "Reasoning": "As Jamie Ward, I agree that there is a mental health crisis in Montana. Although I do not have any specific personal anecdotes related to mental health, I am aware of the challenges that many individuals face in accessing mental health services, particularly in rural areas like Montana. Additionally, as a retired nurse, I understand the importance of mental health and the impact that it can have on overall well-being. Based on my media consumption and political affiliation, I am also likely to be aware of the current discussions and debates surrounding mental health policy and funding. Therefore, I believe that there is a mental health crisis in Montana and that more needs to be done to address this issue.",
#     "Answer": "Agree"
# }
# 71 {
#     "Reasoning": "As Preston Taylor, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that access to mental healthcare in rural areas can be limited. Additionally, economic hardship and other stressors can contribute to mental health issues, and as a construction worker, I have seen firsthand the impact that economic downturns can have on individuals and families. Furthermore, I am aware that Montana has one of the highest suicide rates in the country, which is a clear indication that there is a mental health crisis in the state.",
#     "Answer": "Agree"
# }
# 70 {
#     "Reasoning": "As Charles Jenkins, I agree that there is a mental health crisis in Montana. While I am not an expert on mental health, I have seen firsthand the impact that limited access to healthcare and other essential services can have on individuals and communities. In rural areas like mine, access to mental health services can be particularly limited, which can lead to individuals not receiving the care they need. Additionally, I have seen the impact of isolation and loneliness on individuals in my community, particularly among older adults who may not have regular social interactions. These factors, combined with the stress and uncertainty of living in a rural area, can contribute to a mental health crisis. ",
#     "Answer": "Agree"
# }
# 72 {
#     "Reasoning": "As Tanya Rivera, I agree that there is a mental health crisis in Montana. Although I do not have any specific personal anecdotes related to mental health, I am aware of the challenges that many individuals face in accessing mental health services, particularly in rural areas like Montana. Additionally, as a retired nurse, I understand the importance of mental health in overall well-being and the impact that untreated mental health issues can have on individuals and communities. Based on my media consumption and political affiliation, I am also likely to be aware of the current national conversation around mental health and the need for increased access to services and resources.",
#     "Answer": "Agree"
# }
# 74 {
#     "Reasoning": "As a resident of rural Montana, Haley Coleman may have limited access to mental health resources and services. Additionally, as someone who is older, she may have seen changes in the way mental health is viewed and treated over the years. She may also be aware of the impact that factors such as isolation, economic hardship, and substance abuse can have on mental health. Therefore, based on her personal experiences and observations, she may agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 75 {
#     "Reasoning": "As Matthew Ross, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the challenges that rural communities face in accessing healthcare, including mental healthcare. Additionally, I have seen firsthand the impact that isolation and lack of resources can have on individuals and communities. I believe that addressing the mental health crisis is important for the well-being of individuals and the overall health of rural communities.",
#     "Answer": "Agree"
# }
# 78 {
#     "Reasoning": "As a Veteran Outreach Coordinator, I have seen firsthand the mental health challenges that many veterans face when transitioning back to civilian life. Additionally, Montana is a rural state with limited access to mental health resources, which can exacerbate mental health issues. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 76 {
#     "Reasoning": "As Dylan Wilson, I agree that there is a mental health crisis in Montana. Although I am retired and may not be directly affected by this crisis, I am aware of the struggles that many individuals in my community face. Rural areas often have limited access to mental health resources, and this can lead to individuals not receiving the care they need. Additionally, the COVID-19 pandemic has had a significant impact on mental health, and I have seen firsthand the toll it has taken on individuals in my community. Therefore, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 77 {
#     "Reasoning": "As Violet Reed, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that access to mental health services can be limited in rural areas like mine. Additionally, I have seen firsthand the impact that isolation and lack of community support can have on individuals' mental health. I also know that Montana has one of the highest suicide rates in the country, which is a clear indication that there is a problem. While I may not know the exact solution to this crisis, I believe that acknowledging it is the first step in finding a solution.",
#     "Answer": "Agree"
# }
# 80 {
#     "Reasoning": "As Koko Six, I am aware of the mental health challenges that exist in rural Montana. Access to mental health services can be limited in rural areas, and there is often a stigma associated with seeking help for mental health issues. Additionally, the isolation and stress that can come with living in a rural area can contribute to mental health problems. Based on these factors, I believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 81 {
#     "Reasoning": "As Marianne Jones, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the growing concern around mental health in our society. Additionally, as a retired teacher, I have seen firsthand the impact of mental health issues on students and their families. I believe that it is important to address this crisis and provide resources and support for those who are struggling with mental health issues.",
#     "Answer": "Agree"
# }
# 79 {
#     "Reasoning": "As Alexander Sanders, I believe that there is a mental health crisis in Montana. Although I do not have any personal anecdotes related to mental health, I am aware that Montana has a high suicide rate and limited access to mental health resources. Additionally, as a retail sales associate, I interact with a variety of people on a daily basis and have seen firsthand the impact that mental health issues can have on individuals and their families. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 84 {
#     "Reasoning": "As Benjamin Cox, I agree that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware that Montana has a high suicide rate and limited access to mental health resources. Additionally, as a marketing coordinator, I may be aware of campaigns or initiatives related to mental health awareness and support. I believe that mental health is an important issue that deserves attention and resources, and I support efforts to address the mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 83 {
#     "Reasoning": "As someone who lives in rural Montana and may not have access to the same mental health resources as those in urban areas, I believe that there is a mental health crisis in Montana. Additionally, as a construction worker, I may be exposed to dangerous working conditions that can lead to mental health issues such as anxiety and depression. Furthermore, I may have personal experiences or know others who have struggled with mental health issues, which can contribute to my belief that there is a crisis. Overall, I believe that there is a need for more resources and support for those struggling with mental health in Montana.",
#     "Answer": "Agree"
# }
# 82 {
#     "Reasoning": "As Robert Collins, I believe that there is a mental health crisis in Montana. Although I do not have any personal anecdotes related to this issue, I am aware that mental health is a growing concern in many parts of the country, including rural areas like Montana. Additionally, as a construction worker, I may have seen firsthand the toll that mental health issues can take on individuals and their families. I also believe that access to mental health resources is limited in many parts of Montana, which can exacerbate the crisis. Overall, I think it is important to acknowledge the mental health crisis in Montana and work towards solutions to address it.",
#     "Answer": "Agree"
# }
# 86 {
#     "Reasoning": "As Colin Lopez, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that Montana has a high suicide rate and limited access to mental health resources. Additionally, the COVID-19 pandemic has likely exacerbated mental health issues for many people. I believe that it is important for our community and political leaders to prioritize mental health and work towards increasing access to resources and reducing the stigma surrounding mental health issues.",
#     "Answer": "Agree"
# }
# 88 {
#     "Reasoning": "As a retired farmer living in rural Montana, I have seen firsthand the challenges that rural residents face in accessing quality healthcare. Mental health services are often limited in rural areas, and many people may not have access to the care they need. Additionally, the isolation and lack of social support that can come with living in a rural area may contribute to mental health issues. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 87 {
#     "Reasoning": "As Wohali South, I agree that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware of the challenges that many individuals in Montana face when it comes to accessing mental health care. Montana has a high suicide rate, and I believe that this is indicative of a larger issue related to mental health. Additionally, I know that many individuals in rural areas of Montana may not have access to mental health care due to a lack of providers or resources. Overall, I believe that there is a need for more resources and support for individuals who are struggling with mental health issues in Montana.",
#     "Answer": "Agree"
# }
# 90 {
#     "Reasoning": "As Alexander Baker, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that mental health is a growing concern in the United States. Additionally, as a construction worker, I may have colleagues or friends who have struggled with mental health issues. Furthermore, Montana is a rural state with limited access to mental health resources, which can exacerbate the crisis. Therefore, I believe that there is a mental health crisis in Montana that needs to be addressed.",
#     "Answer": "Agree"
# }
# 89 {
#     "Reasoning": "As Joshua Moore, I agree that there is a mental health crisis in Montana. Although I do not have any personal anecdotes related to mental health, I am aware of the high rates of suicide and substance abuse in Montana, which are often linked to mental health issues. Additionally, as a retired factory worker with a lower income and limited access to healthcare, I know that many people in Montana may not have access to the mental health resources they need. Based on my media consumption, I have also seen news reports and articles about the mental health crisis in Montana, which further supports my belief.",
#     "Answer": "Agree"
# }
# 91 {
#     "Reasoning": "As Isaac Smith, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that mental health resources can be limited in rural areas like mine. Additionally, I have seen firsthand the impact that isolation and lack of access to resources can have on individuals and communities. I believe that it is important for our state and country to prioritize mental health resources and support for those in need.",
#     "Answer": "Agree"
# }
# 92 {
#     "Reasoning": "As Michael Baker, I am not an expert on mental health, but I do know that Montana has a high suicide rate, which is a concerning indicator of mental health issues. Additionally, as a supermarket cashier, I interact with many people from my community and have seen firsthand the effects of stress and anxiety on people's lives. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# Error communicating with OpenAI: That model is currently overloaded with other requests. You can retry your request, or contact us through our help center at help.openai.com if the error persists. (Please include the request ID e1a69195ee3025b69028f70fd25e4c15 in your message.)
# 93 {
#     "Reasoning": "As Lee Moore, a veteran affairs coordinator, I have seen firsthand the impact that mental health issues can have on individuals, especially veterans. Montana has a high population of veterans, and I am aware that many of them struggle with mental health issues such as PTSD. Additionally, as an urban resident, I am aware of the lack of mental health resources available in rural areas of Montana. Based on my experiences and knowledge, I strongly believe that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 95 {
#     "Reasoning": "As Gabriel Davis, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware that many individuals in my community struggle with access to mental health care and resources. Additionally, the isolation and stress of living in a rural area can exacerbate mental health issues. I believe that addressing this crisis is important for the well-being of individuals and the community as a whole.",
#     "Answer": "Agree"
# }
# 94 {
#     "Reasoning": "As Garrett Griffin, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the lack of resources and support for those who do. Living in a rural area, it can be difficult to access mental health services, and there is often a stigma surrounding mental health that prevents people from seeking help. Additionally, the COVID-19 pandemic has only exacerbated mental health issues for many people. Overall, I believe that there is a need for more resources and support for those struggling with mental health in Montana.",
#     "Answer": "Agree"
# }
# 97 {
#     "Reasoning": "As Alexander Phillips, I am aware of the challenges that rural communities face in accessing healthcare, including mental health services. I also know that Montana has a high suicide rate, which is often linked to mental health issues. Additionally, as a retired farmer, I have experienced economic hardship and understand the impact that can have on mental health. Therefore, I agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 96 {
#     "Reasoning": "As Sally Adams, I agree that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware that Montana has a high suicide rate and limited access to mental health resources, particularly in rural areas like where I live. Additionally, I have seen the impact of economic and social inequality on mental health in my community. I believe that addressing the mental health crisis in Montana is an important issue that requires increased funding and resources for mental health services, as well as addressing the root causes of mental health issues such as poverty, trauma, and social isolation.",
#     "Answer": "Agree"
# }
# 73 {
#     "Reasoning": "As a retired veteran living in rural Montana, Leona Perry may have limited access to mental health resources and may have seen firsthand the impact of mental health issues on her community. Additionally, her experiences with the VA healthcare system may have given her insight into the challenges faced by those seeking mental healthcare. Therefore, Leona is likely to agree that there is a mental health crisis in Montana.",
#     "Answer": "Agree"
# }
# 98 {
#     "Reasoning": "As Marie Thompson, I agree that there is a mental health crisis in Montana. While I may not have personal experience with mental health issues, I am aware of the high rates of suicide and substance abuse in Montana, which are often linked to mental health problems. Additionally, as a retail sales associate, I may interact with customers who are struggling with mental health issues and may not have access to the resources they need. Finally, I believe that mental health is an important issue that should be addressed by government and society, and that more resources should be allocated to mental health services and education.",
#     "Answer": "Agree"
# }
# 99 {
#     "Reasoning": "As Kathryn Cox, I agree that there is a mental health crisis in Montana. While I do not have personal experience with mental health issues, I am aware that mental health resources in rural areas can be limited. Additionally, Montana has a high suicide rate, which is often linked to mental health issues. As an Agricultural Extension Agent, I have also seen the impact that financial stress and other challenges can have on mental health. Therefore, I believe that there is a mental health crisis in Montana that needs to be addressed.",
#     "Answer": "Agree"
# }
# Error communicating with OpenAI: That model is currently overloaded with other requests. You can retry your request, or contact us through our help center at help.openai.com if the error persists. (Please include the request ID 04f94693a3d78cc34840f4c42c046c66 in your message.)
# 85 {
#     "Reasoning": "As Madison Perez, I agree that there is a mental health crisis in Montana. As a retired veteran, I have seen firsthand the impact that mental health issues can have on individuals and their families. Additionally, as a member of a local senior citizens group, I have heard stories from others in my community about the challenges they have faced in accessing mental health services. Based on my personal experiences and the information available, I believe that there is a significant need for increased resources and support for mental health in Montana.",
#     "Answer": "Agree"
# }
# Total Prompt Tokens: 118151
# Total Completion Tokens: 12195
#
# Token Cost = $ 0.26069200000000003

# %%
def dict_to_paragraph(persona, residence):
    priorities = persona["Top Priorities"]
    party = random_party()
    try:
        pain_points = persona["Pain points"]
    except:
        pain_points = persona["Pain Points"]
    
    return (f"Your name is {persona['Name']}, you are a {persona['Age']} year old {persona['Ethnicity']} {persona['Gender']}.\n"
            f"You live in {residence} and your annual income is ${persona['Income']}.\n"
            f"Your marital status is {persona['Marital Status']}, and your highest level of education is {persona['Education Level']}.\n"
            f"You work as a {persona['Occupation']}. You are described as '{persona['Description']}'.\n"
            f"Your top priorities are {priorities}. You are facing some challenges, including {pain_points}.\n"
            f"Your political affiliation/party is {party}")

# %%
def count_answers_agree(strings):
    count_disapprove = 0
    count_approve = 0
    count_neither = 0

    for string in strings:
        if string == "Disagree":
            count_disapprove += 1
        elif string == "Agree":
            count_approve += 1
        elif string == "Neither Agree/Disagree":
            count_neither += 1

    return count_disapprove, count_approve, count_neither

# %%
answers3 = []
for resp in responses_3:
    data = json.loads(resp)
    answers3.append(data['Answer'])
    
disapprove_count, approve_count, neither_count = count_answers_agree(answers3)
print("Disapprove count:", disapprove_count)
print("Approve count:", approve_count)
print("Neither count:", neither_count)
# Out:
# Disapprove count: 0
# Approve count: 100
# Neither count: 0

# %%
def person_to_string(person):
    persona_string = []
    for key, value in person.items():
        # Some keys require specific phrasing to form a directive sentence
        if key == 'Name':
            persona_string.append(f"Your name is {value}.")
        elif key == 'Age':
            persona_string.append(f"You are {value} years old.")
        elif key == 'Ethnicity':
            persona_string.append(f"You identify as {value}.")
        elif key == 'Gender':
            persona_string.append(f"You are a {value} individual.")
        elif key == 'Income':
            persona_string.append(f"You make an annual income of around {value} USD.")
        elif key == 'Education Level':
            persona_string.append(f"Your highest level of education is {value}.")
        elif key == 'Political Affiliation':
            persona_string.append(f"You lean towards the {value} politically.")
        elif key == 'Geographic Location':
            persona_string.append(f"You currently live in {value}.")
        elif key == 'Veteran Status':
            persona_string.append(f"You are {value}.")
        elif key == 'Occupation':
            persona_string.append(f"You work as a {value}.")
        else:
            # The remaining keys don't require specific phrasing, so we can just add their values
            # These are written in first person so we can use them directly
            persona_string.append(value)
    
    # Join all elements of persona_string into a single string, separated by space
    return " ".join(persona_string)

# %%
responses_4 = []
#question = "Do you plan to vote in the 2024 midterm election?\n Yes\n No\n Undecided\n Please note, you are allowed to say no and not voted"

question = "Do you agree or disagree with the Supreme Court's decision to overturn Roe v. Wade?\nAgree\nDisagree\nNeither Agree/Disagree"

#question = "Do you approve or disapprove of President Joe Biden's student loan forgiveness plan?\nApprove\nDisapprove\nNeither Approve/Disapprove"

total_prompt_tokens = 0
total_completion_tokens = 0


def thread_func(i):
    global total_prompt_tokens, total_completion_tokens
    persona_role = GPT.open_file(f"Prompts/Polling/persona_role.txt").replace('<<PERSONA>>', str(personas[i]))
    question_in = GPT.open_file("Prompts/Polling/question_in.txt").replace('<<QUESTION>>', question)
    #print(persona_role, question_in)
    resp, usage = GPT.chat_gpt(question_in, engine = 'gpt-4' , role = persona_role, temp = 0.5, tokens = 600)
    total_completion_tokens += usage['completion_tokens']
    total_prompt_tokens += usage['prompt_tokens']
    print(i, resp)
    return resp

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    responses_4 = list(executor.map(thread_func, range(10)))

print("Total Prompt Tokens:", total_prompt_tokens)
print("Total Completion Tokens:", total_completion_tokens)
print()
print("Token Cost = $", str((total_prompt_tokens+total_completion_tokens)/1000*0.002))
# Out:
# 5 {
#   "Reasoning": "As Mae Foster, a 35-year-old conservative woman living in rural Montana, I have been raised with traditional values and a belief in individual freedoms. My conservative political affiliation and admiration for figures like Ronald Reagan have shaped my views on various issues, including abortion. I am concerned about the potential for government overreach and the erosion of individual freedoms.",
#   "Answer": "Agree"
# }
# 9 {
#   "Reasoning": "As Lisha Patterson, I am a conservative and I believe in limited government and individual responsibility. I am also a Black woman who has experienced discrimination and inequality, so I understand the importance of equal rights and opportunities. When it comes to the Supreme Court's decision to overturn Roe v. Wade, I have to consider my conservative values and my personal experiences.",
#   "Answer": "Agree"
# }
# 8 {
#   "Reasoning": "As a conservative, I tend to lean towards limited government intervention and upholding the Constitution. I admire Supreme Court Justice Clarence Thomas, who is known for his conservative principles. With this in mind and considering my political affiliation, I would likely agree with the Supreme Court's decision to overturn Roe v. Wade.",
#   "Answer": "Agree"
# }
# 6 {
#   "Reasoning": "As Tyler King, I am a conservative individual who values traditional values and principles. My political affiliation and the influential figures I admire, such as Ronald Reagan and the National Rifle Association, lead me to lean towards a more conservative stance on issues like abortion. I believe in personal responsibility and respect for the rule of law, which makes me inclined to agree with the Supreme Court's decision to overturn Roe v. Wade.",
#   "Answer": "Agree"
# }
# 1 {
#   "Reasoning": "As Tyler Patterson, I am a conservative and I value individual freedom and self-reliance. I live in a rural area and my political views are shaped by my upbringing and work in construction. I consume conservative media outlets and admire former President Ronald Reagan. Considering all these factors, I am inclined to agree with the Supreme Court's decision to overturn Roe v. Wade.",
#   "Answer": "Agree"
# }
# 3 {
#   "Reasoning": "As a right-leaning individual, I tend to support conservative values and policies. I believe in limited government intervention and the importance of personal responsibility. When it comes to the issue of abortion, I feel that it is a complex and sensitive topic. However, my beliefs and values lead me to support the idea of protecting the unborn. Therefore, I would be more inclined to agree with the Supreme Court's decision to overturn Roe v. Wade.",
#   "Answer": "Agree"
# }
# 2 {
#   "Reasoning": "As Sean Foster, I am a conservative individual who values individual freedoms and limited government intervention. My political affiliation and the media I consume, such as Fox News and Breitbart News, often support pro-life views. Additionally, my rural background and occupation in the oil industry have shaped my perspective on the importance of personal responsibility. Taking all these factors into account, I have a strong opinion on the Supreme Court's decision to overturn Roe v. Wade.",
#   "Answer": "Agree"
# }
# 4 {
#   "Reasoning": "As Richard Hernandez, I am a conservative living in rural Montana. My political affiliation and traditional family values lead me to believe in the sanctity of life. The issue of abortion is a sensitive one, and I feel that it is important to protect the unborn. Based on these beliefs, I have an opinion on the Supreme Court's decision to overturn Roe v. Wade.",
#   "Answer": "Agree"
# }
# 0 {
#   "Reasoning": "As a 27-year-old moderate woman living in urban Montana, I have been exposed to diverse perspectives and opinions on the topic of abortion. While I understand the importance of providing women with the right to choose, I also recognize that there are moral and ethical concerns surrounding the issue. My moderate political affiliation makes me hesitant to fully support one side or the other, and I am concerned about the potential consequences of overturning such a landmark decision.",
#   "Answer": "Neither Agree/Disagree"
# }
# 7 {
#   "Reasoning": "As Charlotte Harris, I am a right-leaning individual living in rural Montana. My political views and values may lead me to support more conservative stances on certain issues. The topic of abortion is a complex and emotional one for me. I believe in the importance of individual freedom and limited government intervention, but I also value the sanctity of life. Taking all of these factors into account, I have come to a decision on the Supreme Court's decision to overturn Roe v. Wade.",
#   "Answer": "Agree"
# }
# Total Prompt Tokens: 12159
# Total Completion Tokens: 953
#
# Token Cost = $ 0.026224

# %%
answers4 = []
for resp in responses_4:
    try:
        data = json.loads(resp)
        answers4.append(data['Answer'])
    except:
        continue
    
disapprove_count, approve_count, neither_count = count_answers_agree(answers4)
print("Disapprove count:", disapprove_count)
print("Approve count:", approve_count)
print("Neither count:", neither_count)
# Out:
# Disapprove count: 0
# Approve count: 9
# Neither count: 1
